# %%
import requests
from urllib.parse import quote
import pandas as pd
from bs4 import BeautifulSoup

# %%
## 필요한거 url
# url = 'http://book.interpark.com'

# %% [markdown]
# http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=354291316&sc.saNo=003003001&bid1=Best_zone&bid2=LiveRanking&bid3=PRD&bid4=001
# http://book.interpark.com/display/collectlist.do?_method=BestsellerHourNew201605&bestTp=1&dispNo=028

# %%
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'}
url = 'http://book.interpark.com/display/collectlist.do?_method=BestsellerHourNew201605&bestTp=1&dispNo=028#'
req = requests.get(url, headers=header)
html = req.text
type(html)
site = 'http://book.interpark.com'

# %%
sub_url = 'http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=354069935&sc.saNo=003003001&bid1=Best_zone&bid2=LiveRanking&bid3=PRD&bid4=001'
sub_req = requests.get(sub_url, headers=header)
sub_html = sub_req.text
type(sub_html)
# Out:
# str

# %%
sub_soup = BeautifulSoup(sub_html,'html.parser')
sub_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>싸니까 믿으니까 인터파크도서</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="인터파크도서, 인터넷 서점, eBook, 비스킷탭, 음반, DVD, 중고책, 중고책서점, 신간도서, 국내도서, 외국도서, 추천도서" name="keywords"/>
# <meta content="문학은 인터파크 도서!" name="description"/>
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content="0" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma">
# <link href="http://bimage.interpark.com/interpark.ico" rel="shortcut icon"/>
# <meta content="no" http-equiv="imagetoolbar">
# <script type="text/javascript">
#         var isFancyAlert = false;    // IMFS에서는 msgAlert 기능을 비활성화시킴
#         var imfsSSLDomain = "https://book.interpark.com"; // com.interpark.util.web.ServletUtils.IMFS_URL_SSL 값을 사용하였으나, Fix 처리 한듯.
#     </script>
# <script src="http://book.interpark.com/static/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/CookieUtil.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/imfs/SessionExpireCheck.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/AC_RunActiveContent.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/html/include/interpark_pcid.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/main_common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/jquery-1.7.2.min.js" type="text/javascript"></script>
# <script src="/gate/ad/adCommonHeader.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body>
# <script type="text/javascript">
#
#     var blnIp3 = false;
#     </script>
# <script src="/gate/html/include/widget.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/html/include/topnav_book_2017.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var _ua = window.navigator.userAgent.toLowerCase();
#     var browser = {
#         model: _ua.match(/(sonyericssonx1i|ipod|iphone)/) ? _ua.match(/(sonyericssonx1i|ipod|iphone)/)[0] : "",
#         skt : /msie/.test( _ua ) && /nate/.test( _ua ),
#         lgt : /msie/.test( _ua ) && /([010|011|016|017|018|019]{3}\d{3,4}\d{4}$)/.test( _ua ),
#         opera : /opera/.test( _ua ) || /opera mobi/.test( _ua ),
#         omniaie : /samsung/.test( _ua ) && /msiemobile/.test( _ua ),
#         ipod : /webkit/.test( _ua ) && /\(ipod/.test( _ua ) ,
#         iphone : /webkit/.test( _ua ) && /\(iphone/.test( _ua ),
#         android : /webkit/.test( _ua ) && /android/.test( _ua )
#     };
#
#   //모바일 피시 화면보기 도입 때문에 예외처리
#     var pcView = "";
#     if(typeof pcView == undefined || 'Y' != pcView) {
#         if( browser.ipod || browser.iphone || browser.android){
#             document.location.href="http://mbook.interpark.com/shop/product/detail?prdNo=354069935&bid4=001&bid3=PRD&bid2=LiveRanking&bid1=Best_zone";
#         }
#     }
#
#     // EGS LOG 수집용 상품번호 테스트
#     EsLogMinorBook.setItemNo("354069935");
# </script>
# <meta content="트렌드 코리아 2022" name="description"/>
# <meta content="트렌드 코리아 2022" name="keywords"/>
# <link href="/styles/pages/shop/detail/detail.css?v=20190420" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var g_stdClsNo = '011003001005'; // 관리분류 (이벤트 띠배너에서 사용)
# var g_stdClsNo3 = '011'; // 관리분류 3자리 (개인화 오늘 본 상품)
# var g_stdClsNo6 = '011003'; // 관리분류 6자리 (상품추천 API에서 사용, 중분류 기준 알고리즘 분리)
# var g_stdClsNo9 = '011003001'; // 관리분류 9자리 (상품고시 정보에서 사용)
# var g_shopNo = '0000400000'; // 상점번호 (상품고시 정보에서 사용)
# var g_dispNo = '028003012001'; // 전시번호 (상품고시 정보, 북카트담기에서 사용)
# var g_evtNo = ''; // 이벤트번호 (북카드담기에서 사용)
# var g_saNo = '003003001'; // 매출분석전시번호 (북카드담기에서 사용)
# var g_saleStatTp = '01'; // 판매상태구분 (북카드담기에서 사용)
# var g_minOrdQty = 1; // 최소주문수량 (북카드담기에서 사용)
# var g_previewFlag = false; // 미리보기 여부
# var loyaltyGrade = 1; // 회원등급 (우측 개인화 레이어에서 사용)
# var g_fancyFlag = false; // 굿즈샵 상품 여부
# var g_wiseLog_param1 = 'book_2015'; // wiseLog 파라메터1
# var g_fancyAddDcRtPer = 0; // 굿즈샵 추가할인율
# var g_ordLayerDisplayFlag = false; // 굿즈# 바로구매 클릭시 뜨는 레이어 노출 여부
# var g_entrBuyTp = '2'; //업체매입유형
#
# var g_orderPossibilityQuantityPaju = Number(923);
# var g_orderPossibilityQuantitySongin = Number(0);
# var g_recommandProductDisplayCount = 12; // 상품추천노출 갯수
#
# var dissectionYn = "N"; // 분철상품여부
# </script>
# <script type="text/javascript">
# $(document).ready(function(){
#     // 시리즈 전체선택
#     $("input.inp_check").click(function() {
#         var seriesNo = $(this).attr("id").replace("seriesAllChk", "");
#         $("input[name=prdNo_series"+seriesNo+"]:enabled").prop('checked', $(this).is(":checked"));
#     });
#
#     $(".btnRed").click(function() { $("#selectBookCartOK").hide(); }); // 북카트레이어 쇼핑계속하기 버튼 클릭시
#
#     // 북카트 담기 클릭시 클릭한 곳에 레이어를 노출하기 위한 이벤트정보 저장
#     $("[data-cart]").click(function(event) {
#         $('[data-cart]').attr("data-cart", "off");
#         $(this).attr("data-cart", "on");
#         $(this).attr("data-client-x", event.clientX);
#         $(this).attr("data-client-y", event.clientY);
#     });
#
#     // 상단 추가혜택 하단 띠배너 영역 배너생성
#     if(!g_fancyFlag) {
#         try {
#             var lineBannerObj = getXmlObj("601120",addWiseLog("tab","book","bn_line","")); // 추가혜택 하단 띠배너
#             if (lineBannerObj.info.length) { // 한개만 노출
#                 var lineBannerHtml = "<a href='"+lineBannerObj.info[0].linkurl+"' target='"+lineBannerObj.info[0].linktarget+"'>";
#                 lineBannerHtml += "<img src='"+lineBannerObj.info[0].imgurl+"' class='bd' alt='"+lineBannerObj.info[0].text1+"'>";
#                 lineBannerHtml += "</a>";
#                 $('.goodsBanBox').html(lineBannerHtml);
#                 $('.goodsBanBox').show();
#             }
#         }catch(e){}
#     }
#
#
#     /* 사은품+기프트+진행중인 이벤트 클릭 및 롤링 처리 Start */
#     var addViewFunc = function(obj) { // 연관도서 더보기 노출 처리
#         $('.ContentTabArea .addView').attr("href","");
#         $('.ContentTabArea .addView').hide(); // 더보기 버튼 비노출
#         if (obj.data().addviewFlag) {
#             $('.ContentTabArea .addView').attr("href",obj.data().addviewHref);
#             $('.ContentTabArea .addView').attr("data-egs",obj.attr("data-addview-egs"));
#             $('.ContentTabArea .addView').show(); // 더보기 버튼 노출
#         }
#     };
#     $('ul.giftTab li[data-show-flag="true"]:first').addClass('active'); // 연관도서영역 좌측 탭 중 첫번째유효탭 활성화class 적용
#     $('.giftContent[data-show-flag="true"]:first').show(); // 연관도서영역 유효탭의 우측영역 display 처리
#     $('ul.giftTab li').click(function (f) {
#         f.preventDefault();
#         if( $(this).hasClass("active") ) return;
#         if( $(this).hasClass('disable') ) return;
#         $("ul.giftTab li").removeClass("active");
#         $(this).addClass("active");
#         $(".giftContent").hide();
#         var activeTab = $(this).data().tabName;
#         $("#" + activeTab).show();
#         if (activeTab == "giftTab1") { fn_wiseLog("relate","freebie","cell"); }
#         else if (activeTab == "giftTab2") { fn_wiseLog("relate","goods","cell"); }
#     });
#     // 연관도서 탭 내 메뉴
#     if($('.ContentTabArea').length) {
#         $('.ContentTabArea li[data-show-flag="true"]:first').addClass('active'); // 연관도서 세부 탭 중 첫번째유효탭 활성화class 적용
#         $('.ContentTabArea li[data-show-flag="true"]').show(); // 연관도서 세부 유효탭 display 처리
#         $('.inTabContent:first[data-show-flag="true"]:first').show(); // 연관도서 세부 유효탭의 상품리스트 display 처리
#         addViewFunc($('#' + $('.ContentTabArea li[data-show-flag="true"]:first').data().tabName)); // 더보기 노출 처리
#         $('.ContentTabArea li').click(function(e) {
#             e.preventDefault();
#             if($(this).hasClass('active')) return;
#             $('.ContentTabArea li').removeClass('active');
#             $(this).addClass('active');
#             $('.inTabContent').hide();
#             var activeTab = $(this).data().tabName;
#             $('#' + activeTab).show();
#             addViewFunc($('#' + activeTab));
#         });
#     }
#     var giftslider1 = $('.giftContent .giftList ul.rolling_Event1').bxSlider({
#         minSlides: 1,
#         maxSlides: 2, // 이 설정값으로 좌우화살표 노출여부가 결정됨. 특정건수 이하면 화살표 비노출을 위해 /webapp/WebContent/renewPark/js/_new/jquery.bxslider.js 커스터마이징
#         slideWidth: 210,
#         slideMargin: 10
#     });
#     var giftslider2 = $('.giftContent .promotionList ul.rolling_Event2').bxSlider({
#         minSlides: 1,
#         maxSlides: 2, // 이 설정값으로 좌우화살표 노출여부가 결정됨. 특정건수 이하면 화살표 비노출을 위해 /webapp/WebContent/renewPark/js/_new/jquery.bxslider.js 커스터마이징
#         slideWidth: 190,
#         slideMargin: 44
#     });
#     $('.giftTab li').on('click',function() {
#         if(giftslider1.length) { giftslider1.reloadSlider(); }
#         if(giftslider2.length) { giftslider2.reloadSlider(); }
#     });
#     /* 사은품+기프트+진행중인 이벤트 클릭 및 롤링 처리 End */
#
#     // 이벤트/기획전영역 띠배너 생성
#     if(!g_fancyFlag) {
#         try {
#             var lineBannerObj = getXmlObj_withoutNum("601044",addWiseLog("bottom","event","bn_big","")); // 최종관리분류 띠배너
#             var loopCnt = 0;
#             var lineBannerHtml = "";
#             if (lineBannerObj.info.length) {
#                 for (var i=0;i<lineBannerObj.info.length;i++) {
#                     var arrDispNo = (lineBannerObj.info[i].text1).split(",");
#                     var dispChk = false; // 띠배너 노출여부
#                     for (var ii=0;ii<arrDispNo.length;ii++) {
#                         if (arrDispNo[ii].length) {
#                             if (g_stdClsNo.substring(0,arrDispNo[ii].length) == arrDispNo[ii]) { // 해당관리분류가 있는지 조회
#                                 dispChk = true;
#                                 break;
#                             }
#                         }
#                     }
#                     if (dispChk) {
#                         lineBannerHtml += "<p><a href='"+lineBannerObj.info[i].linkurl+"' target='"+lineBannerObj.info[i].linktarget+"'><img src='"+lineBannerObj.info[i].imgurl+"' class='bd' alt='"+lineBannerObj.info[i].text2+"'/></a></p>";
#                         loopCnt++;
#                         if (loopCnt == 3) { break; } // 최대3개 노출
#                     }
#                 }
#             }
#             $('.detailEvnetBanner').html(lineBannerHtml); // 띠배너 inner
#             if (lineBannerHtml != "") { // 배너가 있을 경우
#                 $('#eventTitle').show(); // 이벤트/기획전 타이틀 노출
#                 if($("#tabmenu_event").is(':hidden')) { // 이벤트/기획전 메뉴가 비노출이라면.
#                     $('#tabmenu_event').show(); // 이벤트/기획전 탭메뉴 노출
#                     var classNm = $('.menuTab').attr("class");
#                     if(classNm == "menuTab oneTab") { $('.menuTab').attr("class", "menuTab twoTab"); }         // 탭1개 class일경우 탭2개 css로
#                     else if(classNm == "menuTab twoTab") { $('.menuTab').attr("class", "menuTab threeTab"); }  // 탭2개 class일경우 탭3개 css로
#                     else if(classNm == "menuTab threeTab") { $('.menuTab').attr("class", "menuTab fourTab"); } // 탭3개 class일경우 탭4개 css로
#                     else if(classNm == "menuTab fourTab") { $('.menuTab').attr("class", "menuTab fiveTab"); }  // 탭4개 class일경우 탭5개 css로
#                     else if(classNm == "menuTab fiveTab") { $('.menuTab').attr("class", "menuTab"); }          // 탭5개 class일경우 탭6개 css로
#                 }
#                 var cnt = $('#countNumber_event').html(); // 이벤트/기획전 건수
#                 cnt = cnt.replace("(", "").replace(")", "");
#                 cnt = Number(cnt)+Number(loopCnt);
#                 $('#countNumber_event').html("("+cnt+")");
#             }
#         }catch(e){}
#     }
#
#     // [중단영역 (이 도서의 연관상품 하단) 띠배너 생성] 이었으나 변경됨 IPMS-2570
#     // 좌측 귀배너 하단 (1개)
#     try {
#         var lineBannerObj = getXmlObj_withoutNum("601097",addWiseLog("event","bn","big","")); // 최종상품 띠배너 - 도서
#         var lineBannerHtml = "";
#         if (lineBannerObj.info.length) {
#             var i = Math.floor(Math.random() * lineBannerObj.info.length);
#             lineBannerHtml = "<a href='"+lineBannerObj.info[i].linkurl+"' target='"+lineBannerObj.info[i].linktarget+"'>";
#             lineBannerHtml += "<img class='bd' src='"+lineBannerObj.info[i].imgurl+"' alt='"+lineBannerObj.info[i].text1+"'></a>";
#         }
# //         $('.inc_midBan').html(lineBannerHtml); // 띠배너 inner
#         $('.leftEventBanner').html(lineBannerHtml); // 귀배너 최하단 inner
#         if (lineBannerHtml) { // 배너가 있을 경우
#             $('.leftEventBanner').show();
#         }
#     }catch(e){}
#
#     // 중단영역 (이 도서의 연광상품 상단) 반쪽 띠배너 생성 (전시번호 하나로 두개 영역 관리 IPMS-44485)
#     try {
#         var lineBannerObj = getXmlObj_withoutNum("601087","bid1=AD&bid2=bookDetail_2015&bid3=hotbanner");
#         var lineBannerHtml = "";
#         var lineBannerLeftHtml = "";
#         var lineBannerRightHtml = "";
#         var lineBannerUrl = "";
#         var lineBannerWiseLog = "";
#         if (lineBannerObj.info.length) {
#             $('.middleBannerWrap').show();
#             for (var i=0;i<lineBannerObj.info.length;i++) {
#                 lineBannerWiseLog = "&bid4=bigbn_02";
#                 if (i % 2 == 0) { lineBannerWiseLog = "&bid4=bigbn_01"; }
#                 lineBannerUrl = lineBannerObj.info[i].linkurl;
#                 lineBannerUrl += lineBannerWiseLog;
#                 lineBannerHtml = "<li><a href='"+lineBannerUrl+"' target='"+lineBannerObj.info[i].linktarget+"'><img src='"+lineBannerObj.info[i].imgurl+"' alt=''></a></li>";
#                 if (i % 2 == 0) { lineBannerLeftHtml += lineBannerHtml; } // 짝수는 좌측배너
#                 else { lineBannerRightHtml += lineBannerHtml; } // 홀수는 우측배너
#             }
#         }
#         $('#bannerListLeft').html(lineBannerLeftHtml); // 띠배너 inner
#         $('#bannerListRight').html(lineBannerRightHtml); // 띠배너 inner
#         $('.middleBannerWrap #bannerListLeft').bxSlider({
#             mode: 'fade',
#             slideWidth: 488,
#             slideMargin: 0,
#             pager:false,
#             randomStart:true, // 랜덤처리
#             speed:10
#         });
#         $('.middleBannerWrap #bannerListRight').bxSlider({
#             mode: 'fade',
#             slideWidth: 488,
#             slideMargin: 0,
#             pager:false,
#             randomStart:true, // 랜덤처리
#             speed:10
#         });
#     }catch(e){}
#
#     $('.middleBannerWrap .bannerWrap').on({
#         mouseover:function(){
#             $(this).find('.bx-controls').show();
#         },
#         mouseleave: function(){
#             $(this).find('.bx-controls').hide();
#         }
#     });
#
#
#     // 좌측 귀배너 상단 (롤링)
#     try {
#         var lineBannerObj = getXmlObj_withoutNum("601086","bid1=AD&bid2=bookDetail_2015&bid3=hotbanner&bid4=left"); // 상품페이지-핫배너New
#         var lineBannerHtml = "";
#         if (lineBannerObj.info.length) {
#             $('.leftRollBanWrap').show();
#             for (var i=0;i<lineBannerObj.info.length;i++) {
#                 lineBannerHtml += "<li><a href='"+lineBannerObj.info[i].linkurl+"' target='"+lineBannerObj.info[i].linktarget+"'>";
#                 lineBannerHtml += "<img src='"+lineBannerObj.info[i].imgurl+"' alt='"+lineBannerObj.info[i].text1+"'></a></li>";
#             }
#         }
#         $('.banList').html(lineBannerHtml);
#         $('#groupBanWrap .banList').bxSlider({
#             mode: 'fade',
#             slideWidth: 88,
#             slideMargin: 0,
#             pagerType:'short',
#             randomStart:true, // 랜덤처리
#             speed:10
#         });
#         if (lineBannerObj.info.length == 1) {
#             $('.leftRollBanWrap').find('.bx-controls').hide();
#         }
#     }catch(e){}
#
#     // 좌측 귀배너 하단 (1개)
#     try {
#         var lineBannerObj = getXmlObj_withoutNum("601064",""); // 전사마케팅배너-최종
#         var lineBannerHtml = "";
#         if (lineBannerObj.info.length) {
#             var i = Math.floor(Math.random() * lineBannerObj.info.length);
#             lineBannerHtml = "<a href='"+lineBannerObj.info[i].linkurl+"' target='"+lineBannerObj.info[i].linktarget+"'>";
#             lineBannerHtml += "<img src='"+lineBannerObj.info[i].imgurl+"' alt='"+lineBannerObj.info[i].text1+"'></a>";
#         }
#         $('.groupBanBox').html(lineBannerHtml);
#     }catch(e){}
#
#     /* 플로팅 배너 Start */
#     var dAdObj = getXmlObj_withoutNum("601060",addWiseLog("floating","bn","01",""));
#     var dAdObj0 = getXmlObj_withoutNum("601070",addWiseLog("floating","bn","01",""));
#     var floatHtml = "";
#     if(dAdObj0.info.length) {
#         var cnt = 0;
#         var prdNos = "";
#         for(var i=0; i<dAdObj0.info.length;i++){
#             if(dAdObj0.info[i].text1 == '354069935'){
#                 prdNos = dAdObj0.info[i].text1;
#                 cnt = i;
#             }
#         }
#         if(prdNos.indexOf('354069935') >= 0){
#             floatHtml += "<img src='"+dAdObj0.info[cnt].imgurl+"' alt='' usemap='#float_banner'/>";
#             floatHtml += "<map name='float_banner'>";
#             floatHtml += "    <area shape='circle' coords='58,59,54' onFocus='this.blur()' href='#' onclick='directOrd_v2('"+prdNos+"');return false;' target='"+dAdObj0.info[cnt].linktarget+"'/>";
#             floatHtml += "    <area shape='rect' coords='89,109,102,124' href='#' onclick='hideEvent();fn_wiseLog(\"floating\",\"bn\",\"close\");return false;'>";
#             floatHtml += "</map>";
#         }else if(dAdObj.info.length){
#             var dBannerRd = Math.floor(Math.random() * dAdObj.info.length);
#             floatHtml += "<img src='"+dAdObj.info[dBannerRd].imgurl+"' alt='"+dAdObj.info[dBannerRd].text1+"' usemap='#float_banner'/>";
#             floatHtml += "<map name='float_banner'>";
#             floatHtml += "    <area shape='circle' coords='58,59,54' onFocus='this.blur()' href='"+dAdObj.info[dBannerRd].linkurl+"' target='"+dAdObj.info[dBannerRd].linktarget+"'/>";
#             floatHtml += "    <area shape='rect' coords='89,109,102,124' href='#' onclick='hideEvent();fn_wiseLog(\"floating\",\"bn\",\"close\");return false;'>";
#             floatHtml += "</map>";
#         }
#     }else if(dAdObj.info.length){
#         var dBannerRd = Math.floor(Math.random() * dAdObj.info.length);
#         floatHtml += "<img src='"+dAdObj.info[dBannerRd].imgurl+"' alt='"+dAdObj.info[dBannerRd].text1+"' usemap='#float_banner'/>";
#         floatHtml += "<map name='float_banner'>";
#         floatHtml += "    <area shape='circle' coords='67,67,64' onFocus='this.blur()' href='"+dAdObj.info[dBannerRd].linkurl+"' target='"+dAdObj.info[dBannerRd].linktarget+"'/>";
#         floatHtml += "    <area shape='rect' coords='114,130,133,114' href='#' onclick='hideEvent();fn_wiseLog(\"floating\",\"bn\",\"close\");return false;'>";
#         floatHtml += "</map>";
#     }
#     if(floatHtml != "" && g_entrBuyTp == "2") {
#         $("#floating_step1").html(floatHtml);
#         $("#floating_step1").show();
#     }
#     /* 플로팅 배너 End */
#
#     fn_ajax_getViewCnt("354069935"); // 조회수 조회
#     fn_ajax_glovalDelv("354069935"); // 미주직접배송 가능여부
#     fn_ajax_productUseWrite("0", "354069935", "08", 1); // 기대평
#
#     // TODOs: 이북 중고일때는 mallDisplayDto.getStdPrdNo() 넘겨야함
#     if(!g_fancyFlag) {
#         fn_ajax_productReview("354069935", 1, "W"); // 리뷰
#     }
#
#
#     if(g_fancyFlag) { fn_ajax_getNotice_fancy(354069935, g_stdClsNo9); } // 굿즈샵 상품정보제공고시 영역 생성
#     else { fn_ajax_getNotice(354069935, g_stdClsNo9); } // 상품정보제공고시 영역 생성
#
#     /* 추천 API Start */
#     if(!g_fancyFlag) {
#         if(fn_isLogin_cookie()) {
#             fn_ajax_similarity("354069935", ""); //일치도(로그인한 사용자만 노출)
#         }
#         fn_ajax_similarBookProductList("354069935", "", "best"); //이 책과 내용이 비슷한 책
#
#         fn_ajax_viewNBuyTogether_withBest("354069935", "0", "best"); //이 책을 조회한 회원들이 같이 본 책, 이 책을 구매한 회원들이 구매한 책
#
#         fn_ajax_likeInfo("354069935", ""); //좋아요 수 및 좋아요 여부 조회
#
#         fn_ajax_crossAir("354069935"); // 크로스추천 (항공)
#
#     }
#     /* 추천 API End */
#
#     // 굿즈샵일경우
#     if(g_fancyFlag) {
#         // 굿즈샵 옵션 선택시
#         $('.goodsSelectOption select').on('change', function() {
#             fn_wiseLog("option","list","total");
#             var fancy = jQuery.parseJSON($(this).val());
#             if (fancy) {
#                 if(/[^0123456789]/g.test(fancy.price)) {
#                     alert("선택하신 옵션은 품절된 상품이라 선택이 불가합니다.");
#                 } else {
#                     if ($("tr#optionList"+fancy.prdNo).length == 0) {
#                         addOption_fancy(fancy); // 옵션 추가
#                     } else {
#                         changeOption_fancy(fancy.prdNo, "plus"); // 갯수 증가
#                     }
#                 }
#             }
#         });
#         if ($('.goodsSelectOption select').length == 0) { // 단품일때만
#             var totPrice = Number($(".discountPrice em").html().replace(/,+/g, '')); // 굿즈샵 할인적용가 (최초노출 금액)
#             $(".goodsTotalPrice em").html(Number(totPrice).toLocaleString('en').replace(".00", ""));
#             $(".goodsTotalPrice").show();
#             $(".goodsOrderAmount").show();
#             $(".goodsOrderAmount").html($(".goodsOrderAmount").html()+"<input type='hidden' id='fancy_chkID' name='fancy_chkID' value=\"354069935,"+g_saNo+","+g_saleStatTp+"\">");
#         }
#     }
# });
#
# /* 굿즈샵 Start */
# // 굿즈샵 옵션 추가
# function addOption_fancy(fancy) {
#     var innerHtml = "";
#     innerHtml += "<tr id='optionList"+fancy.prdNo+"'>";
#     innerHtml += "    <th>"+fancy.prdNm+"</th>";
#     innerHtml += "    <td>";
#     innerHtml += "        <input type='text' value='"+g_minOrdQty+"' class='iText' onkeyup='changeOption_fancy(\""+fancy.prdNo+"\", \"onEvent\")' onkeypress='onlyNumber();' onblur='onlyNumber2(this, "+g_minOrdQty+");' >";
#     innerHtml += "        <span class='amountControl'>";
#     innerHtml += "            <a href='#' onclick='changeOption_fancy(\""+fancy.prdNo+"\", \"plus\"); return false' class='amountUp'>추가</a>";
#     innerHtml += "            <a href='#' onclick='changeOption_fancy(\""+fancy.prdNo+"\", \"minus\"); return false' class='amountDown'>제거</a>";
#     innerHtml += "        </span>";
#     innerHtml += "    </td>";
#     innerHtml += "    <td>";
#     innerHtml += "        <span class='price'>";
#     innerHtml += "            <em>"+Number(fancy.price).toLocaleString('en').replace(".00", "")+"</em>";
#     innerHtml += "            <span class='currency'>원</span>";
#     innerHtml += "            <a href='#' onclick='delOption_fancy(\""+fancy.prdNo+"\");return false;' class='delete'>제거</a>";
#     innerHtml += "            <input type='hidden' id='fancy_chkID' name='fancy_chkID' value=\""+fancy.prdNo+","+g_saNo+","+fancy.saleTp+"\">";
#     innerHtml += "        </span>";
#     innerHtml += "    </td>";
#     innerHtml += "</tr>";
#     $('.goodsSelectList tbody').append(innerHtml);
#     sumOption_fancy(fancy.prdNo);
# }
#
# // 굿즈샵 옵션 제거
# function delOption_fancy(prdNo) {
#     $("tr#optionList"+prdNo).remove();
#     sumOption_fancy(prdNo);
# }
#
# // 굿즈샵 수량 변경
# function changeOption_fancy(prdNo, div) {
#     var limitNum = 9999; // 주문가능수량 (IPMS-4218 : 기존 999 -> 9999 확대 2017.08.10 by 이준한)
#     var cnt = $("tr#optionList"+prdNo+" input").val();
#     if(cnt < 1) { cnt = 1; } // 최소값
#     if(cnt > limitNum) { cnt = limitNum; } // 최대값
#     if(div == 'minus' && cnt > 1) { cnt = Number(cnt) - 1; } // minus
#     else if(div == 'plus' && cnt < limitNum) { cnt = Number(cnt) + 1; } // plus
#     else if(div == 'onEvent'){} // 직접입력
#     $("tr#optionList"+prdNo+" input.iText").val(cnt);
#     sumOption_fancy(prdNo);
# }
#
# // 굿즈샵 합계
# function sumOption_fancy(prdNo) {
#     $('.goodsSelectWrap').removeClass('selected'); // 비노출 처리
#     $(".goodsTotalPrice").hide();
#     if($(".goodsSelectList tr").length) { // 옵션이 한개라도 있을 경우 노출 처리
#         $('.goodsSelectWrap').addClass('selected');
#         $(".goodsTotalPrice").show();
#     }
#
#     // 해당 옵션 상품가격 계산 Start
#     var price = 0;
#     var fancy = "";
#     $('.goodsSelectOption select option').each(function() {
#         fancy = jQuery.parseJSON($(this).val());
#         if (fancy && fancy.prdNo == prdNo) { price = Number(fancy.price.replace(/,+/g, '')); }
#     });
#     var cnt = $("tr#optionList"+prdNo+" input.iText").val();
#     $("tr#optionList"+prdNo+" .price em").html(Number(price*cnt).toLocaleString('en').replace(".00", ""));
#     // 해당 옵션 상품가격 계산 End
#
#     // 전체 상품가격 계산 Start
#     var totPrice = 0;
#     // var totPrice_floor = 0;
#     var loopPrdNo = 0;
#     $('.goodsSelectList tr').each(function() {
#         loopPrdNo = $(this).attr("id").replace(/[^0123456789]/g, "");
#         totPrice += Number($(this).find(".price em").html().replace(/,+/g, '')); // 선택된 옵션의 SUM
#     });
#     if (totPrice == 0) { totPrice = Number($(".discountPrice em").html().replace(/,+/g, '')); } // 선택된 옵션이 없을 경우 기본 값 처리
#     // if (totPrice >= 15000) { totPrice = totPrice_floor; } // 15000원 이상일 경우 25% 추가할인
#     $(".goodsTotalPrice em").html(Number(totPrice).toLocaleString('en').replace(".00", ""));
#     // 전체 상품가격 계산 End
# }
#
# // 바로구매 버튼 클릭
# function directOrdFancy() {
#     if($(".goodsTotalPrice").is(':visible')) {
#         var totPrice = 0;
#         var loopPrdNo = 0;
#         var fancy = "";
#         // 25% 할인된 금액이 아닌 현재 금액 (25% 할인된 금액이 15000원이 안되면 레이어가 또 노출되기에 25% 할인 전 단가로 계산)
#         $('.goodsSelectList tr').each(function() {
#             loopPrdNo = $(this).attr("id").replace(/[^0123456789]/g, "");
#             $('.goodsSelectOption select option').each(function() {
#                 fancy = jQuery.parseJSON($(this).val());
#                 if (fancy && fancy.prdNo == loopPrdNo) {
#                     price = Number(fancy.price.replace(/,+/g, '')); // 옵션단가
#                     cnt = $("tr#optionList"+loopPrdNo+" input.iText").val(); // 옵션수량
#                     totPrice += Number(price*cnt);
#                 }
#             });
#         });
#         if(g_ordLayerDisplayFlag) { $(".ly_moreShopping").show(); } // 레이어노출 상품은 레이어 노출
#         else { directOrd_fancy_pre('fancy_chkID'); } // 레이어비노출 상품은 바로구매
#     } else {
#         alert("선택하신 상품이 없습니다.\n상품을 선택하신후 버튼을 눌러주십시오. ");
#     }
# }
#
# // 바로구매를 위한 상품배열 생성
# function directOrd_fancy_pre(key) {
#     var prdKey = document.getElementsByName(key);
#     var prdNoList = new Array;
#     var prdNoList2 = new Array;
#     var j=0;
#     for (var i=0; i < prdKey.length; i++) {
#         var prdKeyItem = prdKey.item(i);
#         prdNoList[j] = prdKeyItem.value.split(',')[0]; // modify by 요한. KEY값이 [상품번호, CNT] 로 되있는경우도 있기때문에
#         if (prdKey.length == 1 && $("tr#optionList"+prdNoList[j]).length == 0) { // 단품
#             prdNoList2[j] = document.Goods.PRD_QTY_.value;
#         } else { // 옵션
#             prdNoList2[j] = $("tr#optionList"+prdNoList[j]+" input.iText").val();
#         }
#         j++;
#     }
#     if(j == 0) {
#         alert("선택하신 상품이 없습니다.\n상품을 선택하신후 버튼을 눌러주십시오.");
#         return;
#     } else {
#         var prdArr = new Array(prdNoList.length);
#         for (var i = 0; i < prdNoList.length; ++i) {
#             prdArr[i] = (prdNoList[i]+"," +prdNoList2[i]);
#         }
#         directOrd_fancy(prdArr, key);
#     }
# }
#
# //바로구매
# function directOrd_fancy(sendArray, key) {
#     if(!fn_isLogin_cookie() && fn_isGray()) { // 비로그인, 그레이상품 : 인증페이지로
#         location.href='http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=354069935&sc.evtNo='+g_evtNo+'&sc.dispNo='+g_dispNo+'&chk=Y';
#         return false;
#     } else if(fn_isLogin_cookie() && fn_isGray() && fn_isUnderAge(19)) { // 로그인, 그레이상품, 19세미만
#         alert("해당 상품은 19세미만의 청소년이 구매할 수 없습니다. ");
#         return false;
#     } else {
#         if (g_previewFlag) { return false; }
#         if (ordCntCheck() != "") { alert(ordCntCheck()); } // 보유수량 및 주문 수량 체크
#         var frm = document.Goods;
# //         if(ok(frm)){ } // 추후 필요하면 추가
#         frm.action = "https://book.interpark.com/order/tmpordlist.do?useSSL=YES";
#         frm["_method"].value="saveDirectTempOrder";
#         if(sendArray.length == 1) {
#             frm.DIR_PRD_NO.value = sendArray[0].split(',')[0];
#             frm.DIR_PRD_QTY.value = sendArray[0].split(',')[1];
#         } else {
#             for(var i=0; i<sendArray.length; i++){
#                 if(i == 0) {
#                     frm.DIR_PRD_NO.value = sendArray[i].split(',')[0];
#                     frm.DIR_PRD_QTY.value = sendArray[i].split(',')[1];
#                 } else {
#                     var DIR_PRD_NO = document.createElement("input");
#                     DIR_PRD_NO.type ='hidden';
#                     DIR_PRD_NO.name = 'DIR_PRD_NO';
#                     DIR_PRD_NO.id = 'DIR_PRD_NO';
#                     DIR_PRD_NO.value = sendArray[i].split(',')[0];
#                     frm.appendChild(DIR_PRD_NO);
#
#                     var DIR_PRD_QTY = document.createElement("input");
#                     DIR_PRD_QTY.type= 'hidden';
#                     DIR_PRD_QTY.name = 'DIR_PRD_QTY';
#                     DIR_PRD_QTY.id = 'DIR_PRD_QTY';
#                     DIR_PRD_QTY.value = sendArray[i].split(',')[1];
#                     frm.appendChild(DIR_PRD_QTY);
#
#                     var DIR_SHOP_NO = document.createElement("input");
#                     DIR_SHOP_NO.type= 'hidden';
#                     DIR_SHOP_NO.name = 'DIR_SHOP_NO';
#                     DIR_SHOP_NO.id = 'DIR_SHOP_NO';
#                     DIR_SHOP_NO.value = "0001300000";
#                     frm.appendChild(DIR_SHOP_NO);
#
#                     var DIR_DISP_NO = document.createElement("input");
#                     DIR_DISP_NO.type= 'hidden';
#                     DIR_DISP_NO.name = 'DIR_DISP_NO';
#                     DIR_DISP_NO.id = 'DIR_DISP_NO';
#                     DIR_DISP_NO.value = g_saNo;
#                     frm.appendChild(DIR_DISP_NO);
#                 }
#             }
#         }
#         frm.submit();
#
#         var prdList = getFancyPrdList(key);
#         if(prdList != '') {
#             pushGADetail('fancy', prdList); //GA태깅
#         }
#     }
# }
#
# //옵션상품 북카트담기 버튼 클릭
# function fn_addCartList_fancy(key) {
#     if(!fn_isLogin_cookie() && fn_isGray()) { // 비로그인, 그레이상품 : 인증페이지로
#         location.href='http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=354069935&sc.evtNo='+g_evtNo+'&sc.dispNo='+g_dispNo+'&chk=Y';
#         return false;
#     }
#     var cartKey = document.getElementsByName(key);
#     var prdNos = "";
#     for (var i=0; i < cartKey.length; i++) {
#         if(prdNos != "") { prdNos += ","; }
#         prdNos += cartKey.item(i).value.split(',')[0];
#     }
#     document.Goods.gubun.value = 'fancy'; // callBack 함수로 fn_addCartList_fancy 이쪽을 타기 위해 설정
#     bookcartcheckIframe.bookCartCheckFancy(prdNos, "fancy", key);
#
# }
#
#
# //GA 태깅 - fancy 상품정보 생성
# function getFancyPrdList(key) {
#     var prdKey = document.getElementsByName(key);
#     var prdList = new Array;
#     var hdelvMafcEntrNm = "미래의창";
#
#     for (var i=0; i < prdKey.length; i++) {
#         var prdKeyItem = prdKey.item(i);
#         var prd = {};
#
#         prd.id = prdKeyItem.value.split(',')[0];
#         prd.brand = hdelvMafcEntrNm;
#
#         if(prdKey.length == 1 && $("tr#optionList" + prd.id).length == 0) {
#             prd.name = $(".prod_title p").contents().eq(0).text();
#             prd.price = $(".discountPrice .price").text().replace(/\,/g,'');
#             prd.quantity = document.Goods.PRD_QTY_.value;
#         } else {
#             prd.name =$("#optionList" + prd.id + " th").text();
#             prd.quantity = $("tr#optionList" + prd.id + " input.iText").val();
#             prd.price = ($("#optionList" + prd.id + " .price em").text().replace(/\,/g,'')) / prd.quantity;
#         }
#
#         prd.price = isNaN(prd.price) ? 0 : prd.price;
#         prdList[i] = prd;
#     }
#     if(prdKey.length == 0) {
#     	return '';
#     } else {
#     	return prdList;
#     }
# }
#
#
# //bookcartcheckIframe.bookCartCheckFancy 호출 후 callBack
# function bookCartCheckConfirm_fancy(str, key) {
#     var checkConfirm = "N";
#     if (str == 'Y') {
#         if (confirm("이미 북카트에 담겨진 상품이 포함되어 있습니다.\n주문 수량을 추가하시겠습니까?")) {
#             checkConfirm = "Y";
#         }
#     } else { checkConfirm = "Y"; }
#     document.Goods.gubun.value = ''; // 초기화
#     if (checkConfirm == "Y") {
#         var formObj = document.getElementById("execForm");
#         if(formObj == null) {
#             return;
#         } else {
#             //기존 데이터가 있으면 삭제한다.
#             for(i = formObj.elements.length - 1; i >= 0; i--) {
#                 formObj.removeChild(formObj.elements.item(i));
#             }
#         }
#         var checkCnt=0; //체크박스에 체크된 체크박스 갯수
#         var saleStatCnt=0;  //판매중,예약판매인 상품 갯수
#         var cartInsertLength;   //장바구니에 담을 갯수
#         var cartPrdNo;  //상품번호
#         var cartPrdQty; //상품수량
#         var cartShopNo; //상점번호
#         var cartDispNo; //전시번호
#         var cartEvtNo;  //이벤트번호
#         var saleStat;  //판매상태
#         var cartKey = document.getElementsByName(key);
#         var cartKeyItem;
#         for (var i=0; i < cartKey.length; i++) {
#             cartKeyItem = cartKey.item(i);
#             cartPrdNo  = formObj.elements["CART_PRD_NO_" +checkCnt];
#             cartPrdQty = formObj.elements["CART_PRD_QTY_"+checkCnt];
#             cartShopNo = formObj.elements["CART_SHOP_NO_"+checkCnt];
#             cartDispNo  = formObj.elements["CART_DISP_NO_"+checkCnt];
#             cartEvtNo = formObj.elements["CART_EVT_NO_"+checkCnt];
#             if(cartPrdNo == null || typeof(cartPrdNo) == 'undefined') {
#                 cartPrdNo = document.createElement("input");
#                 cartPrdNo.setAttribute("type", "hidden");
#                 cartPrdNo.setAttribute("name", "CART_PRD_NO_" + checkCnt);
#                 cartPrdQty = document.createElement("input");
#                 cartPrdQty.setAttribute("type", "hidden");
#                 cartPrdQty.setAttribute("name", "CART_PRD_QTY_" + checkCnt);
#                 cartShopNo = document.createElement("input");
#                 cartShopNo.setAttribute("type", "hidden");
#                 cartShopNo.setAttribute("name", "CART_SHOP_NO_" + checkCnt);
#                 cartDispNo = document.createElement("input");
#                 cartDispNo.setAttribute("type", "hidden");
#                 cartDispNo.setAttribute("name", "CART_DISP_NO_" + checkCnt);
#                 cartEvtNo = document.createElement("input");
#                 cartEvtNo.setAttribute("type", "hidden");
#                 cartEvtNo.setAttribute("name", "CART_EVT_NO_" + checkCnt);
#                 formObj.appendChild(cartPrdNo);
#                 formObj.appendChild(cartPrdQty);
#                 formObj.appendChild(cartShopNo);
#                 formObj.appendChild(cartDispNo);
#                 formObj.appendChild(cartEvtNo);
#             }
#             saleStat = cartKeyItem.value.split(',')[2];
#             if (saleStat=="01" || saleStat=="09") { // 판매중,예약판매 상품만 카운트
#                 cartPrdNo.value = cartKeyItem.value.split(',')[0];
#                 if ($('.goodsSelectOption select').length == 0) {
#                     cartPrdQty.value = document.Goods.PRD_QTY_.value;
#                 } else {
#                     cartPrdQty.value = $("tr#optionList"+cartPrdNo.value+" input.iText").val();
#                 }
#                 cartShopNo.value = "0001300000"; // 2014.09.23 구매경로분석작업
#                 cartDispNo.value = cartKeyItem.value.split(',')[1];
#                 cartEvtNo.value = "" ;
#                 saleStatCnt++;
#             }
#             checkCnt++;
#         }
#         if( checkCnt==0 ) { //선택된 체크박스가 하나도 없는경우..
#             alert("선택하신 상품이 없습니다.\n상품을 선택하신후 버튼을 눌러주십시오. ");
#             return;
#         }else if( checkCnt!=saleStatCnt ) { //선택된 상품중 판매중,예약판매가 아닌 상품이 포함된 경우
#             alert("북카트에는 판매중/예약판매 상품만 담을 수 있습니다.\n상품을 다시 선택하신후 버튼을 눌러주십시오.");
#             return;
#         }else {
#             cartInsertLength = formObj.elements["CART_PRD_NO_" +checkCnt];
#             if(cartInsertLength == null)  {
#                 cartInsertLength = document.createElement("input");
#                 cartInsertLength.setAttribute("type", "hidden");
#                 cartInsertLength.setAttribute("name", "CART_INSERT_LENGTH");
#                 formObj.appendChild(cartInsertLength);
#             }
#             cartInsertLength.value = checkCnt;
#             if ($("[data-cart=on]").length) {saveShoppingCartByFormPop(formObj.name, Number($("[data-cart=on]").attr("data-client-x")), Number($("[data-cart=on]").attr("data-client-y"))); } // 북카트담기 레이어 노출
#             else {
#                 saveShoppingCartByForm(formObj.name);
#             } // 북카트담기 후 alert 노출
#
#             var prdList = getFancyPrdList(key);
#             if(prdList != '') {
#                 pushGAAddToCart('fancy', prdList); //GA태깅
#             }
#         }
#     }
# }
# /* 굿즈샵 End */
#
# // 상단 사은품 셀렉트 박스에서 사은품 클릭시
# function fn_presentClick(presentNo, presentParentNo) {
#     var saleStatTp = $('#PRESENT_SALE_STAT_TP'+presentNo).val();
#     if (saleStatTp == "01" || saleStatTp == "09") { // 판매중 or 예판 일때만 추가
#         var presentParentNo = $('#PRESENT_PARENT_NO'+presentNo).val();
#         var addFlag = "Y";
#         $("li[name=presentList]").each(function() {
#             if($(this).is(':visible')) {
#                 var loopPresentNo = $(this).attr("id").replace("presentList","");
#                 if (presentParentNo == $('#PRESENT_PARENT_NO'+loopPresentNo).val()) {
#                     addFlag = "N";
#                 }
#             }
#         });
#         if (addFlag == "Y") {
#             $("li#presentList"+presentNo).show();
#             $("li#presentListLayer"+presentNo).show();
#             $(".totalPriceBox").show();
#             fn_presentSelBoxTxt($("li#presentRight"+presentNo+" .prodName").text()); // 선택시 선택한 사은품명 셋팅
#             fn_presentCalc();
#         } else {
#             alert("선택하신 사은품이 있습니다.\n삭제 후 다시 선택해 주시기 바랍니다.");
#         }
#     } else {
#         alert("선택하신 사은품은 품절된 사은품이라 선택이 불가합니다.");
#     }
# }
#
# // 사은품 제거
# function fn_presentCancle(presentNo) {
#     $("li#presentList"+presentNo).hide();
#     $("li#presentListLayer"+presentNo).hide();
#     fn_presentSelBoxTxt("선택하세요. (본 상품과 함께 구매 가능합니다.)"); // 제거시 초기화
#     fn_presentCalc();
# }
#
# // 선택한 사은품 명칭 셋팅
# function fn_presentSelBoxTxt(txt) {
#     $('#selBox2 .giftSelect').text(txt);
#     $('#selBox3 .giftSelect').text(txt);
# }
#
# // 사은품 금액 및 건수 재계산
# function fn_presentCalc() {
#     var itemCnt = $("li[name=presentList]:visible").length;
#     if (itemCnt == 0) {
#         $(".totalPriceBox").hide();
#         $(".giftNum").hide();
#         $(".plusNum").hide();
#         $(".purple").hide();
#         $(".boxTotalBuy > .plus").hide();
#         $(".bt_downArrow").hide();
#     } else {
#         if($('.totalPriceBox').is(':hidden')) { $(".totalPriceBox").show(); }
#         $("#addItemCnt").html("("+itemCnt+"개)");
#         $(".bt_downArrow").html("외 <span>"+itemCnt+"</span>건");
#         var presentPrice = 0;
#         $("li[name=presentList]").each(function() {
#             if($(this).is(':visible')) {
#                 var presentNo = $(this).attr("id").replace("presentList","");
#                 if (!isNaN(Number($('#PRESENT_PRICE'+presentNo).val()))) {
#                     presentPrice = Number(presentPrice) + Number($('#PRESENT_PRICE'+presentNo).val());
#                 }
#             }
#         });
#         var strPresentPrice = Number(presentPrice).toLocaleString('en').replace(".00", "");
#         $(".giftNum").html(strPresentPrice+"<span>P</span>");
#         $(".purple").html(strPresentPrice+"<span class='small'>P</span>");
#         if (presentPrice > 0) {
#             $(".giftNum").show();
#             $(".plusNum").show();
#             $(".purple").show();
#             $(".boxTotalBuy > .plus").show();
#         } else {
#             $(".giftNum").hide();
#             $(".plusNum").hide();
#             $(".purple").hide();
#             $(".boxTotalBuy > .plus").hide();
#         }
#         if($('.bt_downArrow').is(':hidden')) { $(".bt_downArrow").show(); }
#     }
# }
#
# //관련이미지 리사이즈
# function fn_exImageResize(str){
#     var img = new Image();
#     img.src = str.src
#     var varWidth = img.width;
#     var varHeight = img.height;
#     if(varWidth > 740){
#         var newWidth = 740;
#         var newHeight = Math.round(varHeight*740/varWidth);
#         str.width = newWidth;
#         str.height = newHeight;
#     }
# }
#
# // 신작알림 SMS 신청
# function fn_smsAuthor(authorNo, authorNm) {
#     var url = makeWiseLog("bottom","Author","SMS_New","/contents/personDicSmsApply.do?_method=initial&prsnNo="+authorNo+"&prsnName="+authorNm);
#     var newwindow = window.open(url, "smsSeriesPop", "width=540, height=460, left=0,right=0,status=no,toolbar=no,menubar=no,location=no,scrollbars=yes,resizable=yes");
# }
#
# // 시리즈 신간알림 SMS신청
# function fn_smsSeries(sNo) {
#     var url = makeWiseLog("bottom","series","SMS_New","/communication/PopupSmsMgt.do?_method=seriesInfo&sc.seriesNo=" + sNo);
#     var newwindow = window.open(url, "smsSeriesPop", "width=530, height=480, left=0,right=0,status=no,toolbar=no,menubar=no,location=no,scrollbars=yes,resizable=yes");
# }
#
# // 판매알림 SMS신청
# function fn_productVorvertrag(prdNo) {
#     var url = makeWiseLog("infor","SMS","New","/communication/PopupSmsMgt.do?_method=saleInfo&sc.prdNo="+prdNo+"&sc.prdKind=book");
#     var newwindow = window.open(url, "smsReqPop", "width=500, height=480, left=0,right=0,status=no,toolbar=no,menubar=no,location=no,scrollbars=yes,resizable=yes");
# }
#
#
# // SNS (facebook, twitter) 연동
# function openSNS(type) {
#     var url = encodeURIComponent("http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.saNo=003007005&sc.prdNo=354069935&bookblockname="+type+"&booklinkname=prd");
#     if(type == "facebook"){
#         url = encodeURIComponent("http://book.interpark.com/product/SnsCommon.do?_method=share&sc.prdNo=354069935");
#     }
#     window.open("/product/SnsCommon.do?_method=snsProduct&type="+type+"&url="+url+"&text=%5B%C0%CE%C5%CD%C6%C4%C5%A9%B5%B5%BC%AD%5D%C6%AE%B7%BB%B5%E5+%C4%DA%B8%AE%BE%C6+2022+%B1%E8%B3%AD%B5%B5%7C%B9%CC%B7%A1%C0%C7%C3%A2&bookblockname=prd&booklinkname="+type+addWiseLog("locat","SNS",type,"&"));
# }
#
# /* 상품이미지 하단 버튼 클릭이벤트 Start */
# // 크게보기 (부록도 같이 사용되었으나 2016.02.25이후로 별도 사용)
# function viewPrdItem(shopNo, prdNo, viewTp, choiceYn, paramStr) {
#     var param = "&sc.shopNo=" + shopNo;
#     param += "&sc.prdNo=" + prdNo;
#     param += "&sc.viewTp=" + viewTp;
#     param += "&sc.choiceYn=" + choiceYn;
#     param += addWiseLog("left","icon",paramStr,"&");
#     var features = "width=706,height=558,left=0,right=0,status=no,toolbar=no,menubar=no,location=no,scrollbars=yes,resizable=yes";
#     window.open("/product/ProductDetailImage.do?_method=detail" + param, "", features);
# }
#
# //부록 조회
# function fn_appendix_popup(prdNo) {
#     var url = makeWiseLog("left","icon","appendix","/product/BookDisplay.do?_method=appendixPopup&sources=prdDetail&prdNo="+prdNo);
#     var newwindow = window.open(url, "appendixPopup", "width=780, height=654, left=140,top=140,status=no,toolbar=no,menubar=no,location=no,scrollbars=yes,resizable=yes");
# }
#
# // 음악 미리듣기
# function startMusic(obj){
#     var arrEmbed = document.body.getElementsByTagName("EMBED");
#     for(i=0 ; i < arrEmbed.length ; i++){
#         arrEmbed[i].stop();
#     }
#     document.all[obj].play();
#     setTimeout("stopMusic('"+obj+"')",65000);
# }
# function stopMusic(obj){
#     document.all[obj].stop();
# }
# /* 상품이미지 하단 버튼 클릭이벤트 End */
#
# // 카드사 포인트 교환 클릭
# function fn_cardPoint() {
#     window.open('http://event.okpoint.co.kr/event/gateway?c_code=c00000013&e_code=e00000186&s_code=s00000187');
# }
#
# /* 쿠폰받기 Start */
# // 쿠폰받기 팝업
# function openPopFreeCoupon(couponNo,couponPblctNo,check,freeVal) {
#     var form = document.fmCouponIssue;
#     form["freeYn"].value = freeVal;
#     form["sc.couponNo"].value = couponNo;
#     form["sc.couponPblctNo"].value = couponPblctNo;
#     form["sc.check"].value = check;
#     form["multiYn"].value = "N";
#     couponLoginChk(form);
#     form.submit();
# }
#
# // 로그인 체크. 로그인되어 있으면 iframe에 submit. 안되어 있으면 팝업에 submit
# function couponLoginChk(form) {
#     if(fn_isLogin_cookie()) {
#         form.target = "confirmFrm";
#         form["methodNm"].value = "parent";
#     }else{
#         window.open('about:blank', 'popConfirmFrm', 'width=300, height=400');
#         form.target = "popConfirmFrm";
#         form["methodNm"].value = "opener";
#     }
# }
#
# function openPopFreeCoupons() {
#     if(document.getElementsByName("ARR_COUPON_NO").length) {
#         var form = document.fmCouponIssue;
#         form["multiYn"].value = "Y";
#         couponLoginChk(form);
#         form.submit();
#     } else {
#         alert("다운받을 쿠폰이 없습니다.")
#     }
# }
#
# // 쿠폰받기 클릭 후 CouponConfirmProduct.jsp 리턴
# function result(str) {
#     if(str !== "") { resultFree(str,'N'); }
# }
#
# //쿠폰받기 클릭 후 CouponConfirmProduct.jsp 리턴
# function resultFree(str, freeStr) {
#     if (freeStr == "Y") {
#         if (str == "Y") {
#             alert("이미 무료배송쿠폰이 발급되었습니다. 마이북쇼핑>나의할인쿠폰에서 쿠폰확인이 가능합니다.");
#         } else if(str == "A") {
#             alert("무료배송쿠폰이 발급되었습니다. 주문시 사용하세요.");
#         } else if(str == "E") {
#             alert("발급 가능한 쿠폰이 없습니다.");
#         }
#     } else {
#         if (str == "Y") {
#             alert("이미 쿠폰을 발급받으셨습니다.");
#         } else if(str == "A") {
#             alert("쿠폰 받기가 완료되었습니다.");
#         } else if(str == "E") {
#             alert("발급 가능한 쿠폰이 없습니다.");
#         }
#     }
# }
#
# //쿠폰일괄받기 클릭 후 CouponConfirmProduct.jsp 리턴
# function resultFreeMulti(str) {
#     if(str == "A") {
#         alert("쿠폰 전체 다운받기가 완료되었습니다.\n(발급수량 제한이 있는 쿠폰의 경우 다운받기가 안될 수 있습니다.)");
#     } else if (str == "AY") {
#         alert("일부 이미 발급된 쿠폰을 제외하고 쿠폰 전체 다운받기가 완료되었습니다.");
#     } else if (str == "Y") {
#         alert("이미 쿠폰을 발급받으셨습니다.");
#     } else if(str == "AE") {
#         alert("일부 쿠폰을 제외하고 전체 다운받기가 완료되었습니다.");
#     } else if(str == "E") {
#         alert("발급 가능한 쿠폰이 없습니다.");
#     }
# }
# /* 쿠폰받기 End */
#
# /* 나의 배송지 찾기 Start */
# //배송정보항목의 변경 버튼 클릭 시
# function openZipPopup(){
#     if(fn_isLogin_cookie()) {
#         openZipcodeApi("setAddrDoroCallback@@myDelv");//배송지변경 팝업띄우기
#     } else {
#         if(confirm("로그인이 필요한 서비스입니다.\n로그인하시겠습니까?")) {
#             location.href = "/member/login.do?_method=initial&historyGoCnt=-1";
#         }
#     }
# }
#
# /**
#  * 도로명 주소 팝업 페이지로부터 전달받은 배송지 주소 정보를 처리합니다. (callback function)
#  * from ZipcodeDoroPopup.jsp / https://book.interpark.com/basicdata/ZipcodeDoroPopup.do?_method=initial&callback=setAddrDoroCallback
#  * @param resultJson: 배송지 관련 테이블에 매칭되는 JSON 객체
#  * @param sourceJson: ZipcodeDoroDto 클래스의 속성과 매칭되는 JSON 객체
#  */
# function setAddrDoroCallback(resultJson, sourceJson) {
#     insZipCode(resultJson);
# }
#
# // 배송지 선택 클릭시 (DB 배송지변경)
# function insZipCode(resultJson){
#     var url = "/member/DeliveryInfo.do?_method=save";
#     var parameters = "&zipCd="+resultJson['zipNo']+"&zipAddr="+resultJson['zipAddr'];
#     deliver_requestAjax(url, parameters, "text", deliveryInfo);
# }
#
# // 우편번호 찾기 ajax
# function deliver_requestAjax(url, parameters, responseType, callbackFunc){
#     var encodedParam = encodeURI(parameters); //POST 방식일 경우에는 인코딩을 해 주어야 한다.
#     var xmlHttp = createDelvHttp();
#     xmlHttp.open("post", url, true);
#     var varResponseStatusCode = "";
#     var varResponseHeaders = "";
#     var varResponseContents = "";
#     xmlHttp.onreadystatechange = function() {
#         if (xmlHttp.readyState==4) {
#             varResponseStatusCode = xmlHttp.status;
#             varResponseHeaders = xmlHttp.getAllResponseHeaders();
#             if (xmlHttp.status==200) {
#                 if(responseType == "xml"){
#                     varResponseContents = xmlHttp.responseXML;
#                 }else if(responseType == "text"){
#                     varResponseContents = xmlHttp.responseText;
#                 }
#                 callbackFunc(varResponseContents);
#             }
#         }
#     }
#     xmlHttp.setRequestHeader("Content-Type", "application/x-www-form-urlencoded; charset=UTF-8");
#     xmlHttp.send(parameters);
#     this.responseStatusCode = varResponseStatusCode;
#     this.responseHeaders = varResponseHeaders;
#     this.responseContents = varResponseContents;
# }
#
#
#
# // 배송지 선택 callback
# function deliveryInfo(result){
#     result = result.replace(/(^\s*)|(\s*$)/g, ""); //Trim() 처리
#     if(result=="SUCCESS"){
#         if(fn_isLogin_cookie()) {
#             if(g_fancyFlag) {
#                 $(".deliveryRow .changeAddressWrap").html("");
#             } else {
#                 $("#delvInfo1").remove();
#                 $("#delvInfo2").remove();
#             }
#         }
# 		deliveryDisSet();
#     }
# }
#
# // 변경된 배송지 정보 조회
# function deliveryDisSet() {
#     requestDelvAjax("/product/PrdCommonCheck.do?_method=OneProductDelvInfo2015", "&_style=imfs&sc.prdNo=354069935", "text", resultDelv);
# }
#
# function createDelvHttp() {
#     try {
#         return new XMLHttpRequest();
#     } catch (e) {
#         var objectNames = ["MSXML2.XMLHTTP.5.0",
#             "MSXML2.XMLHTTP.4.0", "MSXML2.XMLHTTP.3.0",
#             "MSXML2.XMLHTTP", "Microsoft.XMLHTTP"];
# ...
# 	                 htmlStr += '   </a>';
# 	                 htmlStr += '</li>';
# 	        }
#
#             document.getElementById("naverPowerLink").style.display = 'block';
#             document.getElementById("powerLinkArea").innerHTML = htmlStr;
#         }
#     }
# </script>
# <script type="text/javascript">
#     NAVER_ADPOST_V2({
#         channel: "interparkbook.ch3",
#         pageSize: 3,
#         test: false,
#         keywordGroup : "인터파크도서_공통",
#         mock: false
#     });
# </script>
# <div class="powerLink" id="naverPowerLink" style="display:none;padding:30px 0 0 0">
# <div class="productInner">
# <div class="powerLinkHeader">
# <h3 class="title">
# 	        파워링크 <small> 광고 </small>
# </h3>
# <div class="apply">
# <a href="https://saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank">신청하기</a>
# </div>
# </div>
# <div class="powerLinkContent">
# <ul id="powerLinkArea"> </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- // 네이버CPC 파워링크 광고 -->
# </div>
# </div>
# <!-- ////////////////// 상품최종 끝 ////////////////// -->
#
# <!--// ## Container S ## -->
# <!-- ## 뷰투게더 관련한 와이지 로그 수집 iframe 작업자 : 김범래 작업일 : 2015.10.05  삭제 금지  ## -->
# <iframe src="/html/imfs/product/wiselog.html?tp=gen&amp;prdNo=354069935&amp;saNo=003003001&amp;viewTp=book" style="display:none" title="뷰투게더 관련 와이즈 로그 수집"></iframe>
# <!-- ## welcome QuickMenu Right S ## -->
# <script src="/gate/html/include/skyRightBanner_2015.js" type="text/javascript"></script>
# <script type="text/javascript">
# var g_strTopNavi = '국내도서';
# var g_strTopNavi2 = '경제경영';
# </script>
# <script src="/renewPark/js/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/renewPark/js/_new/last_inc_new.js?ver=20190417" type="text/javascript"></script>
# <script src="/static/js/imfs/common_display.js" type="text/javascript"></script>
# <script src="/renewPark/js/_new/jquery_ui.js" type="text/javascript"></script>
# <script src="/renewPark/js/_new/jquery.rating2.js" type="text/javascript"></script>
# <script language="javascript" src="/static/js/Popup.js"></script> <!-- 배송비변경팝업용 JS -->
# <script src="/renewPark/js/_new/bookDetailDisplayAjax.js?ver=20190417" type="text/javascript"></script> <!-- ajax 처리 js -->
# <script type="text/javascript">
# /*---------------- 마우스 click XY --------------------*/
# $(document).ready(function(){
#     $(".btnLink").click(function(event){
#         var item = $(this).attr("id");
#         var popItem = "popClick_" + item;
#         var parentOffset = $(this).parent().offset();
#         var scrollTop = $(window).scrollTop();
#         var mouseX = event.pageX;
#         var mouseY = event.pageY;
#
#         var browserWidth = document.body.clientWidth;
#         var browserHeight = $(window).height();
#         var parentWrap = $('div#gateCon');
#         var totalWidth = parentWrap;
#         var rightWidth = $("#" + popItem).innerWidth();
#         var rightHeight = $("#" + popItem).innerHeight();
#         var couponTop = ($(this).offset().top) + $(this).height(); // 할인쿠폰 레이어 top 위치
#         var offsetWidth = document.body.offsetWidth;
#         var $incAll_wrap = $('.incAll_wrap').width();
#         var couponRight = ((offsetWidth - $incAll_wrap) / 2) + 2;
#
#         $(".ly_popDarkGray").css("display", "none");
#         $(".ly_popupAllBox").css("display", "");
#
#         if (popItem === 'popClick_lyCPop4') { //할인쿠폰 레이어일 경우
#             $("#" + popItem).css({
#                 "display" : "block",
#                 "top" : couponTop,
#                 "right" : couponRight
#             });
#
#             // 할인쿠폰 레이어 리사이징 on
#             $(window).on('resize.discountPopupLayer', function() {
#                 var resizeOffsetWidth = document.body.offsetWidth;
#                 var resizeCouponRight = ((resizeOffsetWidth - $incAll_wrap) / 2) + 2;
#
#                 if (resizeOffsetWidth <= $incAll_wrap) {
#                     $("#" + popItem).css ({
#                         "right" : 2
#                     });
#                 } else {
#                     $("#" + popItem).css({
#                         "right" : resizeCouponRight
#                     });
#                 }
#             });
#         } else {
#             if(browserWidth > totalWidth){
#                 if(mouseX + rightWidth > browserWidth){
#                   mouseX = browserWidth - rightWidth - ((browserWidth - totalWidth) / 2) - 5;
#                 }else{
#                   mouseX = mouseX - ((browserWidth - totalWidth) / 2);
#                 }
#             }else{
#                 if(mouseX + rightWidth > browserWidth){
#                   mouseX = browserWidth - rightWidth - 5;
#                 }
#             }
#             $("#" + popItem).css({
#                 "display" : "block",
#                 "left" : mouseX,
#                 "top" : mouseY + 10
#             });
#         }
#     });
#
#     /* 20160212 - 추가 */
#     $(".btnPopOver").mouseenter(function(event){
#         var item = $(this).attr("id");
#         var popItem = "popOver_" + item;
#         var parentOffset = $(this).parent().offset();
#         var scrollTop = $(window).scrollTop();
#         var mouseX = event.pageX;
#         var mouseY = event.pageY;
#
#         var browserWidth = document.body.clientWidth;
#         var browserHeight = $(window).height();
#         var parentWrap = $('div.incAll_wrap');
#         var totalWidth = parentWrap.innerWidth();
#         var rightWidth = $("#" + popItem).innerWidth();
#         var rightHeight = $("#" + popItem).innerHeight();
#
#         if(browserWidth > totalWidth){
#             if(mouseX + rightWidth > browserWidth){
#                 mouseX = browserWidth - rightWidth - 5;
#             }
#         }else{
#             if(mouseX + rightWidth > browserWidth){
#                 mouseX = browserWidth - rightWidth - 5;
#             }
#         }
#         $("#" + popItem).css({
#             "display" : "block",
#             "left" : mouseX,
#             "top" : mouseY-5
#         });
#     });
#     $(".btnPopOver").mouseleave(function(){
#         var item = $(this).attr("id");
#         var popItem = "popOver_" + item;
#         $("#" + popItem).css("display", "none");
#     });
#     /* //20160212 - 추가 */
# });
#
# $(function(){
#     var $tabWraper = $('.contentTabWrap');
#     var $contentTab =  $tabWraper.find('a');
#     var $contentWrap = $('.contentsWrap');
#     var tabHeight = $('.contentTabWrap').height();
#     var onTabIdx = 0;
#     var moveTime = 300;
#     var tabMove = function(){
#         var winScrollTop = $(window).scrollTop();
#         var contentHeight = $('#inc_contentWrap').height();
#         var contentOffsetTop = $('#inc_contentWrap').offset().top;
#         if(winScrollTop < contentOffsetTop){
#             $tabWraper.removeClass('fixed1');
#         } else {
#             if(winScrollTop > contentHeight + contentOffsetTop){
#                 $tabWraper.animate({top: -1 * tabHeight }, moveTime);
#             } else {
#                 $tabWraper.addClass('fixed1').removeAttr('style');
#             }
#         }
#         $contentTab.each(function(index){
#             var tabTotalTop = $contentWrap.eq(index).offset().top + $contentWrap.eq(index).height();
#             if(winScrollTop < tabTotalTop - tabHeight ){
#                 onTabIdx = index;
#                 return false;
#             }
#         });
#         $contentTab.parent('li').removeClass('selected');
#         $contentTab.eq(onTabIdx).parent('li').addClass('selected');
#     };
#     $(window).on('load scroll', tabMove);
#     $contentTab.on('click', function(e){
#         var $target = $(this.hash);
#         var targetOffset = $target.offset().top;
#         $('html,body').stop().animate({scrollTop: targetOffset - tabHeight + 10}, moveTime);
#         e.preventDefault();
#     });
# });
#
# $(function(){
#     var stickyNavTop = $('#bookCart_Type1_miniBar').offset().top;
#     var stickyNav = function(){
#         var scrollTop = $(window).scrollTop();
#         if(scrollTop > stickyNavTop) {
#             $('.nav').addClass('sticky').stop().animate({top:0}, 500)
#         } else {
#             $('.nav').addClass('sticky').stop().animate({top:-60}, 500)
#         }
#     };
#     stickyNav();
#     $(window).scroll(function() {
#         stickyNav();
#     });
# });
# </script>
# <!-- GA 태깅 -->
# <script type="text/javascript">
#     var gaCategory = '도서' + '^' + getStdClsNm(1) + '^' + getStdClsNm(2) + '^' + getStdClsNm(3) + '^' + getStdClsNm(4); //상품옵션 : 옵션1^옵션2^옵션3 (띄어쓰기없음)(데이터 없을경우 공백)(중간에 ^ 주의)
#
#     function getStdClsNm(depth) {
#         var stdClsNm = "Book > 경제경영 > 경제 > 경제전망";
#         if(stdClsNm == '' || typeof stdClsNm == 'undefined') {
#             return '';
#         } else {
#             stdClsNm = stdClsNm.split('>');
#             for(var i=0 ; i<stdClsNm.length ; i++) {
#                 stdClsNm[i] = stdClsNm[i].trim();
#             }
#             if(depth <= stdClsNm.length) {
#                 return stdClsNm[depth-1];
#             } else {
#                 return '';
#             }
#         }
#     }
#
#     function getPrdList(arguments, gaPrdInfo) {
#         var prdTp = '';
#         var prdList = [];
#
#         if(arguments.length != 0) {
#             prdTp = arguments[0];
#         }
#
#         if(prdTp == 'ebook') {
#             gaCategory = '도서' + '^' + prdTp + '^' + getStdClsNm(2);
#             gaPrdInfo.id = arguments[1];
#             gaPrdInfo.price = $('#EB_DISP_SALE_UNITCOST' + gaPrdInfo.id ).val();
#             prdList[0] = gaPrdInfo;
#         } else if(prdTp == 'fancy') {
#             prdList = arguments[1];
#         } else {
#         	prdList[0] = gaPrdInfo;
#         }
#
#         return prdList;
#     }
#
#     function getPrdListToJson(prdList) {
#         var gaProducts = [];
#         for(var i=0 ; i<prdList.length ; i++) {
#             gaProducts.push({id:prdList[i].id, name:prdList[i].name, price:Number(prdList[i].price), brand:prdList[i].brand, category:gaCategory, variant: '', quantity:Number(prdList[i].quantity)});
#         }
#         return gaProducts;
#     }
#
#     //바로구매 버튼 클릭 시
#     function pushGADetail() {
#         var gaId = '354069935';
#         var gaName = $('.prod_title p').text();
#         var gaPrice = isNaN($('#DISPOINT_SALE_UNITCOST').val()) ? 0 : $('#DISPOINT_SALE_UNITCOST').val();
#         var gaBrand = $('#hdelvMafcEntrNm').text();
#         var gaQuantity = $('#inpOrderQty').val();
#         var prdList;
#         var gaProducts = [];
#         var gaPrdInfo = {id : gaId, name : gaName, price : gaPrice, brand : gaBrand, quantity : gaQuantity};
#
#         prdList = getPrdList(arguments, gaPrdInfo);
#         gaProducts = getPrdListToJson(prdList);
#
#         dataLayer.push({
#             'event' : 'select',
#             'ecommerce' : {
#                 'select' : {
#                     'products'  : gaProducts
#                 }
#             }
#         });
#
#     }
#
#     //북카트담기 버튼 클릭 시
#     function pushGAAddToCart() {
#         var gaId = '354069935';
#         var gaName = $('.prod_title p').text();
#         var gaPrice = isNaN($('#DISPOINT_SALE_UNITCOST').val()) ? 0 : $('#DISPOINT_SALE_UNITCOST').val();
#         var gaBrand = $('#hdelvMafcEntrNm').text();
#         var gaQuantity = $('#inpOrderQty').val();
#         var prdList;
#         var gaProducts = [];
#         var gaPrdInfo = {id : gaId, name : gaName, price : gaPrice, brand : gaBrand, quantity : gaQuantity};
#
#         prdList = getPrdList(arguments, gaPrdInfo);
#         gaProducts = getPrdListToJson(prdList);
#
#         dataLayer.push({
#             'event' : 'addToCart',
#             'ecommerce' : {
#                 'currencyCode': 'KRW',
#                 'add' : {
#                     'products'  : gaProducts
#                 }
#             }
#         });
#
#     }
#
#     //상품페이지 로드 후
#     $(function() {
#     	var fancyFlag = "false";
#     	var gaId = '354069935';
#         var gaName = $('.prod_title p').text();
#         var gaBrand = $('#hdelvMafcEntrNm').text();
#         var gaPrice = 0;
#         var gaQuantity = 1;
#         var gaProducts = [];
#
#         if(fancyFlag == "true") {
#         	var price = $('.discountPrice').children('.price').text().replace(/,/gi,'');
#             gaPrice = isNaN(price) ? 0 : price;
#         } else {
#             gaPrice = isNaN($('#DISPOINT_SALE_UNITCOST').val()) ? 0 : $('#DISPOINT_SALE_UNITCOST').val();
#         }
#
#         gaProducts.push({id : gaId, name : gaName, price : gaPrice, brand : gaBrand, category: gaCategory, quantity : gaQuantity, variant:''});
#
#         dataLayer.push({
#             'event' : 'detail',
#             'ecommerce' : {
#                 'detail' : {
#                     'products'  : gaProducts
#                 }
#             }
#         });
#     });
#
# </script>
# <!-- 에이스트레이더 ---->
# <script src="//static.tagmanager.toast.com/tag/view/1027" type="text/javascript"></script>
# <script type="text/javascript">
# var gPrdNm = $(".prod_title p").text();
# var gPrice = $("#DISPOINT_SALE_UNITCOST").val();
# if(gPrice == 'undefined' || isNaN(gPrice) ){
#     gPrice = 0;
# }
# var gCategory = $('#locationMenu1').text()==''?'': ( $('#locationMenu1').text() + ( $('#locationMenu2').text()==''?'': '|'+$('#locationMenu2').text() + ( $('#locationMenu3').text()==''?'': '|'+$('#locationMenu3').text() + ($('#locationMenu4').text()==''?'': '|'+$('#locationMenu4').text()) ) ) );
# var gImgUrl = $(".bd").attr('src');
# var gLoc = window.location.href;
#
#  window.ne_tgm_q = window.ne_tgm_q || [];
#  window.ne_tgm_q.push(
#  {
#      tagType: 'detail',
#      device:'web',
#      pageEncoding:'euc-kr',
#      items : [{
#          id: "354069935"/*(필수)ID값입력*/,
#          price:gPrice/*(필수)가격정보입력*/,
#          quantity:"1"/*(필수)갯수정보입력*/,
#          category:gCategory/*카테고리 대|중|소*/,
#          imgUrl:gImgUrl/*img링크값입력 ex)http://example.com/img/img.jpg*/,
#          name:gPrdNm/*(필수)제품명또는 전환메뉴명입력*/,
#          desc:""/*상품상세 설명 text*/,
#          link:gLoc/*상품상세페이지 URL ex)http://example.com/detail/product.html*/
#      }],
#      totalPrice:gPrice/*상품 총 금액 합산*/
#  });
#  </script>
# <!-- //에이스트레이더 ---->
# <!-- FB픽셀 ---->
# <script>
#
# var gPrdNm = $(".prod_title p").text();
# var gPrice = $("#DISPOINT_SALE_UNITCOST").val();
# if(gPrice == 'undefined' || isNaN(gPrice) ){
#     gPrice = 0;
# }
# fbq('track', 'ViewContent', {
#   content_ids: ['354069935'],
#   content_type: 'product',
#   content_category: 'book',
#   content_name: gPrdNm,
#   content_genre: null,
#   content_category_detail: g_dispNo,
#   member_category : _gMemGrd,
#   value: gPrice,
#   currency: 'KRW'
#  });
#
# </script>
# <!-- //FB픽셀 ---->
# <script src="/gate/html/include/sub_book_bottomNew2015.js" type="text/javascript"></script>
# <script language="JavaScript">
# <!--
# 	function showNoticeMsgs(msgs) {
# 		/* imfs 는 액션 설정 메세지 처리 하지 않음
# 		var	tDiv;
# 		var	showHtml;
#
# 		showHtml				= "";
# 		for (var i=0; i<msgs.length; i++) {
# 			if (showHtml != "") {
# 				showHtml	+= " | ";
# 			}
# 			showHtml	+= msgs[i];
# 		}
# 		top.status	= showHtml;
# 		*/
# 	}
# //-->
# </script>
# <!-- yelloexchange SCRIPT Start-->
# <!-- <script type="text/javascript" src="/gate/keyword7/keyword7_solution.js"></script> -->
# <!-- <script type="text/javascript" src="/gate/keyword7/keyword7_search_solution.js"></script> -->
# <!--// yelloexchange SCRIPT End-->
# <!-- Google 리마케팅 태그 코드 Start -->
# <!-- google analytics SCRIPT Start-->
# <script src="/gate/googleAnalytics/google_analytics.js" type="text/javascript"></script>
# <!--// google analytics SCRIPT End-->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 976811730;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/976811730/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
# </img></div>
# </noscript>
# <!-- Google 리마케팅 태그 코드 End -->
# <script src="/gate/ad/adCommon.js" type="text/javascript"></script>
# <form id="execForm" name="execForm"></form>
# <iframe frameboard="0" height="0" name="exec_iframe" scrolling="no" src="about:blank" style="visibility:hidden;" width="0"></iframe>
# </body>
# </html>
# <!-- End of Generate Html -->
# <!-- 위 태그는 html 생성시 꼭 필요한 태그임 지우지 말것 -->

# %%
soup = BeautifulSoup(html,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>싸니까 믿으니까 인터파크도서</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="인터파크도서, 인터넷 서점, eBook, 비스킷탭, 음반, DVD, 중고책, 중고책서점, 신간도서, 국내도서, 외국도서, 추천도서" name="keywords"/>
# <meta content="문학은 인터파크 도서!" name="description"/>
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content="0" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma">
# <link href="http://bimage.interpark.com/interpark.ico" rel="shortcut icon"/>
# <meta content="no" http-equiv="imagetoolbar">
# <script type="text/javascript">
#         var isFancyAlert = false;    // IMFS에서는 msgAlert 기능을 비활성화시킴
#         var imfsSSLDomain = "https://book.interpark.com"; // com.interpark.util.web.ServletUtils.IMFS_URL_SSL 값을 사용하였으나, Fix 처리 한듯.
#     </script>
# <script src="http://book.interpark.com/static/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/CookieUtil.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/imfs/SessionExpireCheck.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/AC_RunActiveContent.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/html/include/interpark_pcid.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/static/js/main_common.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/jquery-1.7.2.min.js" type="text/javascript"></script>
# <script src="/gate/ad/adCommonHeader.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body>
# <script type="text/javascript">
#
#     var blnIp3 = false;
#     </script>
# <script src="/gate/html/include/widget.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/gate/html/include/topnav_book_2017.js" type="text/javascript"></script>
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <!-- 공통변수,함수 include-->
# <script src="/static/js/jquery-1.8.2.min.js" type="text/javascript"></script>
# <script src="/renewPark/js/DisplayOpenSummary.js" type="text/javascript"></script>
# <script src="http://book.interpark.com/renewPark/js/_new/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/static/js/imfs/common_display.js" type="text/javascript"></script>
# <script type="text/javascript">
# //사용자정보중에 회원등급정보 (우측레이어 영역에 중요한부분)
# var loyaltyGrade = 1;
# </script>
# <link href="/styles/pages/bestSeller/rankBest.css?ver=20190314" media="all" rel="stylesheet" type="text/css"/>
# <link href="/styles/pages/shop/detail/detail.css?v=20190420" media="all" rel="stylesheet" type="text/css"/>
# <!-- 공통변수,함수 include-->
# <form action="/display/collectlist.do" id="bestFrm" method="get" name="bestFrm">
# <input id="_method" name="_method" type="hidden" value="BestsellerHourNew201605"/>
# <input id="searchDay" name="searchDay" type="hidden" value="2021.12.06 (월)"/>
# <input id="bestTp" name="bestTp" type="hidden" value="1"/>
# <input id="bestTp" name="dispNo" type="hidden" value="028"/>
# <input id="clickCnb" name="clickCnb" type="hidden" value="Y"/>
# <input id="cltWeek" name="cltWeek" type="hidden"/>
# </form>
# <!-- 커스텀 js는 하단에 있습니다. 개발자 : 김범래-->
# <div id="bookPark">
# <div class="hide">
# <a href="#gnbwrap">주메뉴 바로가기</a>
# <a href="#content">본문 바로가기</a>
# <a href="#footerWrap">하단 바로가기</a>
# </div>
# <!-- ## Container S ## -->
# <div id="container">
# <div id="content">
# <!-- Renewal Version :: Start -->
# <!-- rankBestWrapper :: start -->
# <!-- 좌, 우 귀배너 추가 start -->
# <div class="leftWingWrap" style="display: none;">
# <ul id="leftBannerSection"></ul> <!-- 601049 -->
# </div>
# <div class="rightWingWrap" style="display: none;">
# <ul>
# <li id="RightBannerSectionUp"> </li> <!-- 602027 -->
# <li id="RightBannerSectionDown"> </li> <!-- 601097 -->
# </ul>
# </div>
# <!-- 좌, 우 귀배너 추가 end -->
# <div class="rankBestWrapper">
# <!-- rankBestHeader :: start -->
# <div class="rankBestHeader">
# <h1><img alt="인터파크도서 베스트셀러" src="http://bimage.interpark.com/renewPark/reBookpark/rankChart2016/text/h1_bestSeller.png"/></h1>
# <!-- <div class="suddenRank">
#                         <h3>실시간 급상승</h3>
#                         <div class="rankList">
#                             <ol>
#                                 <li class="down">
#                                     <a href="#">
#                                         <span class="rankNo">10</span>
#                                         <strong class="rankName">2009 선재국어 세트</strong>
#                                         <span class="breadth">
#                                             <span class="icon">하강</span>
#                                             <em>54</em>
#                                         </span>
#                                     </a>
#                                 </li>
#                             </ol>
#                         </div>
#                     </div> -->
# </div>
# <!-- rankBestHeader :: end -->
# <!-- rankBestFilter :: start -->
# <div class="rankBestFilter">
# <!-- categoryHeader :: start -->
# <div class="categoryHeader">
# <h2>
# <a href="#">
# <img alt="카테고리" src="http://bimage.interpark.com/renewPark/reBookpark/rankChart2016/text/h2_category.png"/>
# </a>
# </h2>
# </div>
# <!-- categoryHeader :: end -->
# <!-- contentsHeader :: start -->
# <div class="contentsHeader">
# <!-- rankFilter :: start -->
# <div class="rankFilter">
# <!-- filterSelector :: start -->
# <div class="filterSelector" id="filterSelectorId">
# <ul>
# <li class="current" id="cateTabId1">
# <a class="day" href="#" onclick="cateTab(1)">
# <span>당일</span>
# </a>
# </li>
# <li id="cateTabId2">
# <a class="week" href="#" onclick="cateTab(2)">
# <span>주간</span>
# </a>
# </li>
# <li id="cateTabId3">
# <a class="month" href="#" onclick="cateTab(3)">
# <span>월간</span>
# </a>
# </li>
# <li id="cateTabId4">
# <a class="year" href="#" onclick="cateTab(4)">
# <span>연간</span>
# </a>
# </li>
# </ul>
# </div>
# <!-- filterSelector :: end -->
# <!-- filterPeriod :: start -->
# <div class="filterPeriod" id="filterPeriodId">
# <a href="#">
# <span class="periodStart" id="periodStandardDate">2021년 12월 06일(월) 17:00 기준</span>
# </a>
# <ul class="periodSelector" id="periodSelectorId">
# <li><a href="javascript:searchBest('0211205')"><span class="periodStart">2021.12.05 (일) </span></a></li>
# <li><a href="javascript:searchBest('0211204')"><span class="periodStart">2021.12.04 (토) </span></a></li>
# <li><a href="javascript:searchBest('0211203')"><span class="periodStart">2021.12.03 (금) </span></a></li>
# <li><a href="javascript:searchBest('0211202')"><span class="periodStart">2021.12.02 (목) </span></a></li>
# <li><a href="javascript:searchBest('0211201')"><span class="periodStart">2021.12.01 (수) </span></a></li>
# <li><a href="javascript:searchBest('0211130')"><span class="periodStart">2021.11.30 (화) </span></a></li>
# <li><a href="javascript:searchBest('0211129')"><span class="periodStart">2021.11.29 (월) </span></a></li>
# <li><a href="javascript:searchBest('0211128')"><span class="periodStart">2021.11.28 (일) </span></a></li>
# <li><a href="javascript:searchBest('0211127')"><span class="periodStart">2021.11.27 (토) </span></a></li>
# <li><a href="javascript:searchBest('0211126')"><span class="periodStart">2021.11.26 (금) </span></a></li>
# <li><a href="javascript:searchBest('0211125')"><span class="periodStart">2021.11.25 (목) </span></a></li>
# <li><a href="javascript:searchBest('0211124')"><span class="periodStart">2021.11.24 (수) </span></a></li>
# <li><a href="javascript:searchBest('0211123')"><span class="periodStart">2021.11.23 (화) </span></a></li>
# <li><a href="javascript:searchBest('0201106')"><span class="periodStart">2020.11.06 (금) </span></a></li>
# <li><a href="javascript:searchBest('0201105')"><span class="periodStart">2020.11.05 (목) </span></a></li>
# <li><a href="javascript:searchBest('0201104')"><span class="periodStart">2020.11.04 (수) </span></a></li>
# ...
#                 list +="                   <i class='decoFront'></i>";
#                 list +="                </a>";
#                 list +="               </label>";
#                 list +="           </div>";
#                 list +="           <div class='coverOption'>";
#                 list +="               <ul>";
#                 list +="                   <li class='cart'>";
#                 list +="                       <a href='#' value='"+obj[i].prdNo+"'class='cartGo'><span>CART</span></a>";
#                 list +="                   </li>";
#                 list +="                   <li class='buy'>";
#                 list +="                       <a href='javascript:directOrd("+obj[i].prdNo+");'><span>BUY</span></a>";
#                 list +="                   </li>";
#                 list +="               </ul>";
#                 list +="           </div>";
#                 list +="           <div class='rankNumber digit2'>";
#                 list +=             obj[i].dispPrir; //  랭킹 순위가 태그로 나옴 주의 퍼블에게 미리 요청해야함   예시)  일단위 <span class="rankBtn_ctrl rkNum_B01 "></span>   씹단위 <span class="rankBtn_ctrl rkNum_M09 "></span><span class="rankBtn_ctrl rkNum_M09 "></span> 백단위 :     <span class="rankBtn_ctrl rkNum_S01 "></span><span class="rankBtn_ctrl rkNum_S00 "></span><span class="rankBtn_ctrl rkNum_S00 "></span>
#                 list +="           </div>";
#                 list +="       </div>";
#                 list +="       <div class='itemIcon'>";
#                 if(iconList.length > 0){
#                     for(var j = 0; j <iconList.length ; j++){
#                         if(obj[i].prdNo == iconList[j].prdNo){
#                             if( iconList[j].cltIcn.indexOf('01') > -1){
#                                 // 베스트
#                                 list +="    <span class='bestSeller'>베스트셀러</span>";
#                             }
#                             if( iconList[j].icnTp.indexOf('07') > -1){
#                                 // 인터파크 추천
#                                 list +="    <span class='interparkRecommend'>인터파크추천</span>";
#                             }
#                             if( iconList[j].cltIcn.indexOf('03') > -1){
#                                 // 스테디셀러
#                                 list +="    <span class='steadySeller'>스테디셀러</span>";
#                             }
#                         }
#                     }
#                 }
#                 if(iconListForPresent.length > 0){
#                     for(var j = 0; j <iconListForPresent.length ; j++){
#                         if(obj[i].prdNo == iconListForPresent[j].prdNo){
#                             if( iconListForPresent[j].presentYn.indexOf('Y') > -1){
#                                 // 베스트
#                          //       list +="           <span class='gift'>사은품</span>"; // 추후 적용
#                             }
#                         }
#                     }
#                 }
#                 list +="       </div>";
#                 list +="       <a href='"+obj[i].linkUrl+"&sc.saNo="+ saNoList[saIndex] +"' target='_blank'>";
#                 list +="           <div class='itemName'>";
#                 list +="               <strong>"+obj[i].prdNm.replace("(양장)","")+"</strong>";
#                 list +="           </div>";
#                 list +="           <div class='itemMeta'>";
#                 var editorNm = "";
#                 if(obj[i].editorNm != ""){
#                     editorNm = ": "+obj[i].editorNm;
#                 }
#                 list +="               <span class='author'>"+obj[i].author.substr(0, 70)+editorNm+"</span>";
#                 list +="               <span class='company'>"+obj[i].hdelvMafcEntrNm+"</span>";
#                 list +="           </div>";
#                 // 가격 설정
#                 //판매지수는 가격에서 쿼리함.
#                 prdIdxStr = "";
#                 if(priceList.length > 0){
#                     for(var j = 0; j <priceList.length ; j++){
#                         if(obj[i].prdNo ==priceList[j].prdNo){
#                             var dcRtPer ="";
#                             dcRtPer = priceList[j].dcRtPer;
#                             var blcPointDcRtPer = "";
#                             blcPointDcRtPer = priceList[j].blcPointDcRtPer;
#                             list +="           <div class='priceWrap'>";
#                             list +="               <span class='price'>";
#                             list +="                   <em>"+priceList[j].saleUnitcost+"</em>";
#                             list +="                   <span class='currency'>원</span>";
#                             list +="               </span>";
#                             if(dcRtPer!=null||blcPointDcRtPer!=null||dcRtPer!=""||blcPointDcRtPer!=""){
#                                 list +="               <span class='benefits'> ";
#                                 list +="                   <span>(</span>";
#                                 if(dcRtPer!=null&&dcRtPer!=""){
#                                     list +="                   <span class='discount'>";
#                                     list +="                       <em>"+dcRtPer+"</em>";
#                                     list +="                       <span class='unit'>할인</span>";
#                                     list +="                   </span>";
#                                 }
#                                 if(blcPointDcRtPer!=null&&blcPointDcRtPer!=""){
#                                 list +="                   <span class='save'>";
#                                 list +="                       <em>"+blcPointDcRtPer+"</em>";
#                                 list +="                       <span class='unit'>적립</span>";
#                                 list +="                   </span>";
#                                 }
#                                 list +="                   <span>)</span>";
#                                 list +="               </span>";
#                             }
#                             list +="           </div>";
#
#                             // 판매지수 추가 2017.1.16
#                             var prdIdxVal = priceList[j].prdIdxVal;  //StringUtils.defaultString(dto.getPrdIdxVal(), "0")   ;
#                             //alert(prdIdxVal);
#
#                             if(prdIdxVal == null || "null" ==  prdIdxVal || "0" ==prdIdxVal || "" ==prdIdxVal ) {
#                                 prdIdxVal = "-";
#                             }else{
#                                 prdIdxVal = fnCommas(prdIdxVal); //gate/js/common.js
#                             }
#                             if("[330075799, 330075897, 330075900, 330075901, 330075903, 330075905, 330075908, 330075909, 330075911, 330076144, 283903874, 283903875, 283903876, 283903877, 314035386, 314038074, 314039472, 314040753, 314041736, 314042485, 314043736, 314044436, 314045354, 316241312, 316241849, 316243129, 316244661, 316245317, 316245619, 316246575, 316246999, 316247879, 316248460, 334275776, 334275844, 334275845, 334275846, 334275847, 334275892, 334275894, 334275895, 334275898, 334275902, 334275910, 334275912, 339126309, 339126317, 339126355, 339126388, 339126357, 339126392, 339126386, 339126394, 344575863, 344576106, 344576117, 344576121, 344576122, 344576126, 344576127, 344576129, 348752393, 348752808, 348753008, 348753013, 348753015, 348753018, 348753019, 348753209, 348753212, 348753217, 348753220, 348753221, 348753225, 352180193, 352180401, 352180403, 352180405, 352180409, 352180411, 352180414, 352180415, 352180422, 352180423, 352180424, 352180427, 352180431, 352180432, 352230522]".indexOf(priceList[j].prdNo) == -1) {
# 								prdIdxStr +="       <div class='saleIndex'>";
# 								prdIdxStr +="       <span class='title'>판매지수</span>";
# 								prdIdxStr +="       <em class='indexNumber'>"+prdIdxVal+ "</em>";
# 								prdIdxStr +="       </div>";
# 							}
#                         }
#                     }
#                 }
#
#                 list +="       </a>";
#
#                 if(starPointList.length > 0){
#                     for(var j = 0; j <starPointList.length ; j++){
#                         if(obj[i].prdNo ==starPointList[j].prdNo){
#                             var starPoint = starPointList[j].totGrade;
#                             var starPoint10 = starPointList[j].totGradeD10;
#                             if(starPoint == null || starPoint == "0"){
#                                 starPoint="";
#                             }
#                             if(starPoint10 == null || starPoint10 == ""){
#                                 starPoint10="0";
#                             }
#                             list +="       <div class='reviewStat'>";
#                             list +="           <span class='title'>평점</span>";
#                             list +="           <span class='starRateWrap'>";
#                             list +="               <span class='starRate' style='width:"+starPoint10+"%'>"+starPoint+"</span>";
#                             list +="           </span>";
#                             list +="           <em class='rateNumber'>"+starPoint+"</em>";
#                             list +="       </div>";
#                         }
#                     }
#                 }
#                 //// 판매지수 추가
#                 list += prdIdxStr;
#
#
#                 if(eventList.length > 0){
#                     var tempEvtInt = 0;
#                     list +="       <div class='relatedEvent'>";
#                     list +="           <ul>";
#                     for(var j = 0; j <eventList.length ; j++){
#                         if(obj[i].prdNo ==eventList[j].prdNo){
#                             tempEvtInt++;
#                             if(tempEvtInt<4){
#                                 var tempEvtStr = eventList[j].evtNm;
#                                 if(tempEvtStr.length >= 18){
#                                     tempEvtStr = tempEvtStr.substring(0,18) +"..."
#                                 }
#                                 list +="               <li>";
#                                 list +="                   <a href='"+eventList[j].evtUrl+"' target='_blank'>"+tempEvtStr+"</a>";
#                                 list +="               </li>";
#                             }
#                         }
#                     }
#                     list +="           </ul>";
#                     list +="       </div>";
#                 }
#
#                 list +="   </div>";
#                 list +="</li>";
#             }
#             list +="</ol>";
#             divList.append($(list));
#             // 페이지가 로드된 이후에 셀렉드 박스 숨기기
#             $('#filterPeriodId').removeClass('on');
#         }
#     }
#
#     // 랭킹 히스토리 셀릭트 박스 만들어주기
#     function setTopHistoryList(cltWeek, selectCond, selectDate){
#         bestFrm.cltWeek.value = cltWeek;
#         //기준일 밀어 넣기
#         $('#periodStandardDate').html(selectCond);
#         if(cltWeek != "" ){
#             $(".periodSelector").empty();
#             $('.periodSelector').html(selectDate);
#         }
#     }
#
#     function printProductListPageNavi(totalCnt, cltTp, gubun) {
#
#         //$('.rankBestPagination').hide();
#         pageDiv ="";
#         pageDiv +="<a href='#' class='arrow first'  id='prd_navi_first_span'><span>처음</span></a>";
#         pageDiv +=" <a href='#' class='arrow prev'  id='prd_navi_before_span'><span>이전</span></a> ";
#         pageDiv +=" <span class='numList'> ";
#         pageDiv +=" </span> ";
#         pageDiv +=" <a href='#' class='arrow next' id='prd_navi_after_span'><span>다음</span></a> ";
#         pageDiv +=" <a href='#' class='arrow last' id='prd_navi_last_span'><span>마지막</span></a> ";
#
#         $('.rankBestPagination').html(pageDiv);
#
#         comTotalCnt = totalCnt;
#         totalPage = Math.ceil(comTotalCnt/comRow);
#
#         var naviStr = "";
#
#         startPageIndex = 0; //시작 Page Index 초기화
#         endPageIndex = 0;   //끝   Page Index 초기화
#
#         if(comPageNum < startPageIndex || comPageNum > endPageIndex) {
#             var pageIndex = Math.ceil(comPageNum/pageCount);
#
#             endPageIndex = pageCount * pageIndex;
#             startPageIndex = endPageIndex -  (pageCount-1);
#
#             if(totalPage < endPageIndex){
#                 endPageIndex = totalPage;
#             }
#         }
#
#         for(var i=startPageIndex; i<=endPageIndex; i++) {
#             var cls = "";
#             if(comPageNum == i){
#                 cls = " class='current'";
#             }
#             naviStr += "<a href='javascript:goPaging(" + i + ",\""+cltTp+"\",\""+gubun+"\");' "+cls+">" + i + "</a>";
#         }
#
#         $('.numList').html(naviStr);
#
#         var firstOnClickEvent = "";
#         if(1 < comPageNum) {
#             firstOnClickEvent = "onClick='javascript:goPaging(1, \""+cltTp+"\",\""+gubun+"\");'";
#         }
#         document.getElementById("prd_navi_first_span").innerHTML = "<span "+firstOnClickEvent+">처음</span>";
#
#         var beforeOnClickEvent = "";
#         cursor = "";
#         if(startPageIndex > pageCount) {
#             beforeOnClickEvent = "onClick='javascript:goPaging("+Number(startPageIndex-pageCount)+", \""+cltTp+"\", \""+gubun+"\");'";
#         }
#         document.getElementById("prd_navi_before_span").innerHTML = "<span "+beforeOnClickEvent+">이전</span>";
#
#         var afterOnClickEvent = "";
#         cursor = "";
#         if(Number(endPageIndex*comRow) < comTotalCnt) {
#             afterOnClickEvent = "onClick='javascript:goPaging("+Number(endPageIndex+1)+", \""+cltTp+"\", \""+gubun+"\");'";
#         }
#         document.getElementById("prd_navi_after_span").innerHTML = "<span "+afterOnClickEvent+">다음</span>";
#
#         var lastOnClickEvent = "";
#         cursor = "";
#         if(1<totalPage && comPageNum!=totalPage) {
#             lastOnClickEvent = "onClick='javascript:goPaging("+totalPage+", \""+cltTp+"\", \""+gubun+"\");'";
#         }
#         document.getElementById("prd_navi_last_span").innerHTML = "<span "+lastOnClickEvent+">마지막</span>";
#     }
# </script>
# <script src="/renewPark/js/_new/rankBest.js" type="text/javascript"></script>
# <script src="/gate/html/include/sub_book_bottomNew2015.js" type="text/javascript"></script>
# <script language="JavaScript">
# <!--
# 	function showNoticeMsgs(msgs) {
# 		/* imfs 는 액션 설정 메세지 처리 하지 않음
# 		var	tDiv;
# 		var	showHtml;
#
# 		showHtml				= "";
# 		for (var i=0; i<msgs.length; i++) {
# 			if (showHtml != "") {
# 				showHtml	+= " | ";
# 			}
# 			showHtml	+= msgs[i];
# 		}
# 		top.status	= showHtml;
# 		*/
# 	}
# //-->
# </script>
# <!-- yelloexchange SCRIPT Start-->
# <!-- <script type="text/javascript" src="/gate/keyword7/keyword7_solution.js"></script> -->
# <!-- <script type="text/javascript" src="/gate/keyword7/keyword7_search_solution.js"></script> -->
# <!--// yelloexchange SCRIPT End-->
# <!-- Google 리마케팅 태그 코드 Start -->
# <!-- google analytics SCRIPT Start-->
# <script src="/gate/googleAnalytics/google_analytics.js" type="text/javascript"></script>
# <!--// google analytics SCRIPT End-->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 976811730;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/976811730/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
# </img></div>
# </noscript>
# <!-- Google 리마케팅 태그 코드 End -->
# <script src="/gate/ad/adCommon.js" type="text/javascript"></script>
# <form id="execForm" name="execForm"></form>
# <iframe frameboard="0" height="0" name="exec_iframe" scrolling="no" src="about:blank" style="visibility:hidden;" width="0"></iframe>
# </html></body>
# </html>
# <!-- End of Generate Html -->
# <!-- 위 태그는 html 생성시 꼭 필요한 태그임 지우지 말것 -->

# %%
lis = soup.select('ol>li')
len(lis)
# Out:
# 15

# %%
sub_lis = sub_soup.select('.bInfo_txt>li')
sub_lis[-2]
# Out:
# <li>쪽수 : 452</li>

# %%
li = lis[14]
li
# Out:
# <li>
# <!-- listItem | singleType or setType :: start -->
# <div class="listItem singleType">
# <div class="cover">
# <div class="coverImage">
# <label>
# <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=353614891&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
# <span class="checkBox">
# <input name="_KEY" type="checkbox" value="353614891"/>
# </span>
# <img alt="NFT 레볼루션" src="https://bimage.interpark.com/partner/goods_image/4/8/9/1/353614891s.jpg"/>
# <i class="decoFront"></i>
# </a>
# </label>
# </div>
# <div class="coverOption">
# <ul>
# <li class="cart">
# <a class="cartGo" href="#" value="353614891"><span>CART</span></a>
# </li>
# <li class="buy">
# <a href="javascript:directOrd('353614891');"><span>BUY</span></a>
# </li>
# </ul>
# </div>
# <div class="rankNumber digit2">
# <span class="rankBtn_ctrl rkNum_M01"></span><span class="rankBtn_ctrl rkNum_M04"></span>
# </div>
# </div>
# <div class="itemIcon">
# <span class="bestSeller">베스트셀러</span>
# </div>
# <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=353614891&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
# <div class="itemName"><strong>NFT 레볼루션 </strong></div>
# <div class="itemMeta">
# <span class="author">성소라, 롤프 회퍼, 스콧 맥러플린</span>
# <span class="company">더퀘스트</span>
# </div>
# <div class="priceWrap">
# <span class="price">
# <em>16,200</em>
# <span class="currency">원</span>
# </span>
# <span class="benefits">
# <span>(</span>
# <span class="discount">
# <em>10%</em>
# <span class="unit">할인</span>
# </span>
# <span class="save">
# <em>5%</em>
# <span class="unit">적립</span>
# </span>
# <span>)</span>
# </span>
# </div>
# </a>
# <div class="reviewStat">
# <span class="title">평점</span>
# <span class="starRateWrap">
# <span class="starRate" style="width:98%">9.8</span>
# </span>
# <em class="rateNumber">9.8</em>
# </div>
# <div class="saleIndex">
# <span class="title">판매지수</span>
# <em class="indexNumber">74,787</em>
# </div>
# <div class="relatedEvent">
# <ul>
# <li>
# <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=241291" target="_blank">[기획] 2022, 미래를 전망하...</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- singleType or setType :: end -->
# </li>

# %%
## 순위, 책제목,저자 , 출판사  , 가격(정수로바꾸기 나중에) 발행일 ,  , 쪽수
# main 에서 알수 있는거 제목, 저자 ,출판사  , 가격

# %% [markdown]
# 순위

# %%
rank = li.select('.rankNumber.digit2>span')
# rank[1].split("_")
# rank = rank[1].split("_")
# rank = rank[1]
# rank = rank.split('0')
# rank = rank[1]
# rank
rank_1= rank[0]['class'][1].split('_')[1].split('0')[1]
rank_1
# Out:
# '1'

# %%
rank_2=rank[1]
rank_2=rank_2['class']
# rank_2=rank_2[1]
# rank_2=rank_2.split('_')
# rank_2=rank_2[1]
# rank_2=rank_2.split()
# rank_2=rank_2[0]
# rank_2=rank_2[-1]
rank_2
# Out:
# ['rankBtn_ctrl', 'rkNum_M04']

# %%
rank_1+rank_2
# Out:
# '14'

# %% [markdown]
# 책제목

# %%
bookname = li.select_one('.itemName').string
bookname
# Out:
# '불편한 편의점(15만부 기념 윈터 에디션) '

# %% [markdown]
# 저자

# %%
name = li.select_one('.author').string
name
# Out:
# '김호연'

# %% [markdown]
# 출판사

# %%
publisher = li.select_one('.company').string
publisher
# Out:
# '나무옆의자'

# %% [markdown]
# 가격

# %%
price = li.select_one('.price').get_text().strip().split()
# price = ''.join(price)
price = price[0].split(',')
price = ''.join(price)
int(price)
# Out:
# 16200

# %% [markdown]
# sub_url,발행일, 쪽수

# %%
published_date = sub_lis[-3].string
published_date
# Out:
# '발행 : 2021년 10월 06일'

# %%
number_of_pages =  sub_lis[-2].string
number_of_pages = number_of_pages.split()
number_of_pages = number_of_pages[2]
number_of_pages = int(number_of_pages)
number_of_pages
# Out:
# 452

# %%
rank,bookname,name,publisher,price,published_date,number_of_pages
# Out:
# ([<span class="rankBtn_ctrl rkNum_M01"></span>,
#   <span class="rankBtn_ctrl rkNum_M02"></span>],
#  '불편한 편의점(15만부 기념 윈터 에디션) ',
#  '김호연',
#  '나무옆의자',
#  '12,600원',
#  '발행 : 2021년 10월 06일',
#  452)

# %% [markdown]
# href

# %%
href = li.find('a')['href']
href

sub_url = site + href
sub_url
# Out:
# 'http://book.interpark.com/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=348921505&sc.saNo=003003001&bid1=Best_zone&bid2=LiveRanking&bid3=PRD&bid4=001'

# %%
# rank
len_rank = len(li.select('.rankNumber.digit2>span'))
rank = rank_1+rank_2
rank 
len_rank
# Out:
# 2

# %% [markdown]
# 최종

# %%
lines=[]
for index, li in enumerate(lis):
    rank = li.select('.rankNumber.digit2>span')
    if len(rank)>1:
        rank_1= rank[0]['class'][1].split('_')[1].split('0')[1]
        rank_2=rank[1]['class'][1].split('_')[1].split()[0][-1]
        rank = rank_1+rank_2
    else:   
        rank = rank[0]['class']
        rank[0].split("_")
        rank = li.select_one('.rankNumber.digit2').find('span')['class']
        rank[0].split("_")
        rank = rank[1].split("_")
        rank = rank[1]
        rank = rank.split('0')
        rank = rank[1]


    bookname = li.select_one('.itemName').string
    name = li.select_one('.author').string
    publisher = li.select_one('.company').string
    price = li.select_one('.price').get_text().strip().split()
    price = price[0].split(',')
    price = ''.join(price)
    int(price)
    href = li.find('a')['href']

    sub_url = site + href
    sub_req = requests.get(sub_url)
    sub_html = sub_req.text
    sub_soup = BeautifulSoup(sub_html, 'html.parser')
    published_date = sub_soup.select('.bInfo_txt>li')[-3].string
    number_of_pages = sub_soup.select('.bInfo_txt>li')[-2].string
    number_of_pages = number_of_pages.split()
    number_of_pages = number_of_pages[2]
    number_of_pages = int(number_of_pages)
    
    lines.append([rank,bookname,name,publisher,price,published_date,number_of_pages])

# %%
df = pd.DataFrame(lines, columns=['순위','책제목','저자','출판사','가격','발행일','쪽수'])
df
# Out:
#     순위                                책제목                                 저자  \
# 0    1                      트렌드 코리아 2022        김난도(金蘭都), 전미영, 최지혜, 이향은, 이준영
# 1    2            2022 현직교사들이 들려주는 면접레시피   류은진, 양왕경, 이광한, 이지혜, 양왕경, 이광한, 이지혜
# 2    3                         거인의 포트폴리오                                 강환국
# 3    3                        거꾸로 읽는 세계사                            유시민(柳時敏)
# 4    5                  아직 오지 않은 날들을 위하여                     파스칼 브뤼크네르/이세진 역
# 5    6  작은 별이지만 빛나고 있어(10만 부 기념 한정판 에디션)                                  소윤
# 6    7                       투자는 디테일에 있다                                 김정환
# 7    7                 웰씽킹(Wealthinking)                                켈리 최
# 8    7                         오십에 읽는 논어                                 최종엽
# 9   10      소크라테스 익스프레스(20만 부 기념 윈터 에디션)                        에릭 와이너/김하현 역
# 10  10                     달러구트 꿈 백화점. 2                                 이미예
# 11  12           불편한 편의점(15만부 기념 윈터 에디션)                                 김호연
# 12  13                        달러구트 꿈 백화점                                 이미예
# 13  14                           흔한남매. 9                    흔한남매, 백난도/유난희 그림
# 14  14                          NFT 레볼루션                 성소라, 롤프 회퍼, 스콧 맥러플린
#
#         출판사     가격                 발행일    쪽수
# 0      미래의창  16200  발행 : 2021년 10월 06일   452
# 1      미래가치  42300  발행 : 2021년 11월 12일  1104
# 2    페이지2북스  16200  발행 : 2021년 11월 08일   404
# 3       돌베개  15750  발행 : 2021년 10월 29일   404
# 4     인플루엔셜  14400  발행 : 2021년 11월 12일   320
# 5      북로망스  13500  발행 : 2021년 09월 29일   274
# 6       부케이  16200  발행 : 2021년 12월 10일   424
# 7      다산북스  14400  발행 : 2021년 11월 10일   316
# 8      유노북스  14400  발행 : 2021년 11월 03일   300
# 9      어크로스  16200  발행 : 2021년 11월 26일   524
# 10    팩토리나인  12420  발행 : 2021년 07월 27일   308
# 11    나무옆의자  12600  발행 : 2021년 04월 20일   268
# 12    팩토리나인  12420  발행 : 2020년 07월 08일   300
# 13  미래엔아이세움  12150  발행 : 2021년 12월 09일   192
# 14     더퀘스트  16200  발행 : 2021년 09월 01일   324
