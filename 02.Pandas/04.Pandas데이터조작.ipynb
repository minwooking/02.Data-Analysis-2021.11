# %% [markdown]
# # Pandas - 데이터 조작

# %%
import numpy as np
import pandas as pd

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv',skiprows=1,encoding='EUC-KR') # 설명이면 한줄 건너뛰어야한다. seq , skiprows, encoding 세개로 맞추는거임 
cctv
# Out:
#       구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0      계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1    종로구   1,772      813      0      0    210    150      1    261     85
# 2    중 구   2,333       16    114     87     77    236    240    372    386
# 3    용산구   2,383       34     71    234    125    221    298    351    125
# 4    성동구   3,602      448    125    212    105    339    310    874    390
# 5    광진구   2,588       35     57    100    187     98     52    675    465
# 6   동대문구   2,497    1,090    146     60     29    111    233    136    197
# 7    중랑구   3,296      302     24    253     88    141    161    162    173
# 8    성북구   3,958       83     78    170    230    323    594    460    867
# 9    강북구   2,462        0      0     24     65    105    243      6    392
# 10   도봉구   1,629       39     22     96    181     79    159    134    222
# 11   노원구   2,415        0     97    193     77    516    331    175    216
# 12   은평구   3,791       14      3     44    332    329    555    403    635
# 13  서대문구   2,940      730    253    155    108    137    223    356    237
# 14   마포구   2,421       58     93     77     61    162    454    359    343
# 15   양천구   3,312    1,413    167    181    143    180    350    139    140
# 16   강서구   2,560      55    129    106    213    188    168    506    259
# 17   구로구   4,075      852    216    349    187    268    326    540    488
# 18   금천구   2,374        0      0   178     80    361    133    196    540
# 19  영등포구   3,778      572   136    238    123    209    248    311    658
# 20   동작구   2,297       41     24     25    503    128    253    271    300
# 21   관악구   4,942      428    205    291    513    529    621    687    663
# 22   서초구   3,704      116     75     94     71    563    516   1060    428
# 23   강남구   6,502      124     77     75    597    840   1310    999    748
# 24   송파구   2,854       72     61     86     85    215    148    241    542
# 25   강동구   2,547      332     27    163     49    154    202    273    377
#
#      2019년   2020년  2021년
# 0   11,961  11,132  1,608
# 1        9     200     43
# 2      155     361    289
# 3      307     617      0
# 4      262     461     76
# 5      712     175     32
# 6      209     223     63
# 7     1049     939      4
# 8      714     251    188
# 9     1000     588     39
# 10     198     168    331
# 11     320     386    104
# 12    1057     288    131
# 13     343     397      1
# 14     494     300     20
# 15     274     325      0
# 16    457     356    123
# 17     434     415      0
# 18    369     508       9
# 19     65   1,213       5
# 20     322     419     11
# 21     640     331     34
# 22     358     420      3
# 23     789     942      1
# 24    1068     235    101
# 25     356     614      0

# %% [markdown]
# ㅇ 탐색을위한메소드

# %%
cctv.head() # 위에 보여줌
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
cctv.tail(2) # 아래 보여줌
# Out:
#      구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년 2017년 2018년 2019년 2020년  \
# 24  송파구  2,854       72    61    86    85   215   148   241   542  1068   235
# 25  강동구  2,547      332    27   163    49   154   202   273   377   356   614
#
#    2021년
# 24   101
# 25     0

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     object
#  2   2012년 이전  26 non-null     object
#  3   2012년     26 non-null     object
#  4   2013년     26 non-null     object
#  5   2014년     26 non-null     object
#  6   2015년     26 non-null     object
#  7   2016년     26 non-null     object
#  8   2017년     26 non-null     object
#  9   2018년     26 non-null     object
#  10  2019년     26 non-null     object
#  11  2020년     26 non-null     object
#  12  2021년     26 non-null     object
# dtypes: object(13)
# memory usage: 2.8+ KB

# %%
df = pd.DataFrame(np.random.randint(40,101,20).reshape(4,5),columns=list('ABCDE'), index=list('wxyz')) # 데이타프레임\
df
# Out:
#     A   B   C   D   E
# w  49  74  46  73  91
# x  74  61  80  93  53
# y  68  59  68  66  42
# z  61  72  86  68  92

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, w to z
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int32
#  1   B       4 non-null      int32
#  2   C       4 non-null      int32
#  3   D       4 non-null      int32
#  4   E       4 non-null      int32
# dtypes: int32(5)
# memory usage: 112.0+ bytes
#                A          B          C          D          E
# count   4.000000   4.000000   4.000000   4.000000   4.000000
# mean   63.000000  66.500000  70.000000  75.000000  69.500000
# std    10.739336   7.593857  17.663522  12.355835  25.800517
# min    49.000000  59.000000  46.000000  66.000000  42.000000
# 25%    58.000000  60.500000  62.500000  67.500000  50.250000
# 50%    64.500000  66.500000  74.000000  70.500000  72.000000
# 75%    69.500000  72.500000  81.500000  78.000000  91.250000
# max    74.000000  74.000000  86.000000  93.000000  92.000000

# %% [markdown]
# - sum(),min,max,mean

# %%
df.sum() # axis = 0
# Out:
# A    252
# B    266
# C    280
# D    300
# E    278
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# w    333
# x    361
# y    303
# z    379
# dtype: int64

# %%
df.std(axis=1) # 표준편차
# Out:
# w    18.875911
# x    15.738488
# y    11.036304
# z    12.853015
# dtype: float64

# %%
df.iloc[0:,[4]].mean(axis=0).round(2) # 이것도 가능하네 
df.iloc[[0],0:].mean(axis=1).round(2) # 이것도 가능하네
# Out:
# w    66.6
# dtype: float64

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isna().sum().sum() # 왜 섬 두개쓰는거야 나온결과를 바로 합치려고 섬섬 쓴거임
# Out:
# 869

# %%
titanic.isna().sum().sum()
# Out:
# 177

# %%
titanic.isna().sum() # 결측치 더한 결과
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# embark_town      0
# alive            0
# alone            0
# adult child      0
# dtype: int64

# %%
# age 결측치는 평균으로 대체
titanic['age'].round(4).fillna(titanic.age.mean(),inplace=True)
titanic['age'].round(5)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 889         1       1  male  26.0      0      0  30.00        C  First  man
# 890         0       3  male  32.0      0      0   7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 889        True    C   Cherbourg   yes   True
# 890        True  NaN  Queenstown    no   True

# %%
# embarked 겉측치는 행 삭제
titanic.dropna(subset=['embarked'],inplace=True)
titanic.dropna(subset=['embark_town'],inplace=True)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# deck 컬럼은 컬럼 삭제
#del titanic['deck']
# subset : 행 colums : 열

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [889 rows x 15 columns]

# %%
titanic.drop(columns=['deck'],inplace=True)

# %%
titanic.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 889         1       1  male  26.0      0      0  30.00        C  First  man
# 890         0       3  male  32.0      0      0   7.75        Q  Third  man
#
#      adult_male embark_town alive  alone
# 889        True   Cherbourg   yes   True
# 890        True  Queenstown    no   True

# %% [markdown]
# - apply()

# %%
df = pd.DataFrame(np.random.randint(40,101,20).reshape(4,5),columns=list('ABCDE'), index=list('wxyz')) # 데이타프레임\
df
# Out:
#     A   B   C   D   E
# w  88  67  95  96  50
# x  93  42  70  66  60
# y  96  82  59  43  63
# z  54  74  60  52  80

# %%
# 각열의 최대값과 최소값의 차이
df.apply(lambda x: x.max() -x.min(),axis=0) # 열의 -최대값과 최소값의 차이
# Out:
# A    42
# B    40
# C    36
# D    53
# E    30
# dtype: int64

# %%
df.apply(lambda x: x.max() -x.min(),axis=1) # 행의 -최대값과 최소값의 차이
# Out:
# w    46
# x    51
# y    53
# z    28
# dtype: int64

# %%
# 타이타닉호 승객중 20살이 넘으면 'adult' 그렇지 않으면 child
titanic['adult child'] = titanic.apply(lambda x:'adult' if x.age > 20 else 'child', axis=1) 
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone adult child
# 0      man        True  Southampton    no  False       adult
# 1    woman       False    Cherbourg   yes  False       adult
# 2    woman       False  Southampton   yes   True       adult
# 3    woman       False  Southampton   yes  False       adult
# 4      man        True  Southampton    no   True       adult
# ..     ...         ...          ...   ...    ...         ...
# 886    man        True  Southampton    no   True       adult
# 887  woman       False  Southampton   yes   True       child
# 888  woman       False  Southampton    no  False       child
# 889    man        True    Cherbourg   yes   True       adult
# 890    man        True   Queenstown    no   True       adult
#
# [889 rows x 15 columns]

# %%
# cctv 소수점 없애기
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
cctv.iloc[:,2:] = cctv.iloc[:,2:].apply(lambda x: int(x.replace(',','')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-4d90ef34c297> in <module>
# ----> 1 cctv.iloc[:,2:] = cctv.iloc[:,2:].apply(lambda x: int(x.replace(',','')))
#
# C:\src\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# C:\src\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# C:\src\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# C:\src\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-28-4d90ef34c297> in <lambda>(x)
# ----> 1 cctv.iloc[:,2:] = cctv.iloc[:,2:].apply(lambda x: int(x.replace(',','')))
#
# C:\src\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
cctv.columns

# %%
for colum in cctv.columns[2:]:
    cctv[colum] = cctv[colum].apply(lambda x: int(x.replace(',','')))

# %%
cctv.head()

# %%
df = pd.DataFrame(np.random.randint(40,101,20).reshape(4,5),columns=list('ABCDE'), index=list('wxyz')) # 데이타프레임\
df

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv',skiprows=1,encoding='EUC-KR') # 설명이면 한줄 건너뛰어야한다. seq , skiprows, encoding 세개로 맞추는거임 
cctv

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv',skiprows=1,encoding='EUC-KR') # 설명이면 한줄 건너뛰어야한다. seq , skiprows, encoding 세개로 맞추는거임 
cctv
cctv2 = cctv.iloc[0:,2:]

# %%
cctv2.apply()

# %%
df = pd.DataFrame(np.random.randint(40,101,20).reshape(4,5),columns=list('ABCDE'), index=list('wxyz')) # 데이타프레임\
df

# %%
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv',skiprows=1,encoding='EUC-KR') # 설명이면 한줄 건너뛰어야한다. seq , skiprows, encoding 세개로 맞추는거임 
cctv.head()

# %%
cctv.iloc[:,2:] = cctv.iloc[:,2:].apply(lambda x: x.str.replace(',',''))
cctv

# %%
cctv.iloc[2:,2:] = cctv.iloc[2:,2:].apply(lambda x: x.replace(',','')).astype(int)

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()

# %%
# 1번 문제 해결 
titanic.count()

# %%
titanic.sort_values(by='sex'),titanic.sort_values(by='age'),titanic.sort_values(by='class'),titanic.sort_values(by='sex')

# %%
titanic.sort_values(by='alive')

# %% [markdown]
# 타이타닉호 승객의 평균 나이를 구하라.
#
# 타이타닉호 승객중 여성 승객의 평균 나이를 구하라.
#
# 타이타닉호 승객중 1등실 선실의 여성 승객의 평균 나이를 구하라.

# %%
# 평균 나이
titanic.age.mean()

# %%
# 타이타닉호 승객중 여성 승객의 평균 나이를 구하라.
titanic['sex'] = titanic.apply(lambda x:'female' if x.sex == 'female' else False)
